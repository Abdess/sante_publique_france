# %% [markdown]
# <h1>Table des matières<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction-:-Préparer-des-données-pour-un-organisme-de-santé-publique" data-toc-modified-id="Introduction-:-Préparer-des-données-pour-un-organisme-de-santé-publique-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction : Préparer des données pour un organisme de santé publique</a></span><ul class="toc-item"><li><span><a href="#Santé-publique-France" data-toc-modified-id="Santé-publique-France-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Santé publique France</a></span></li><li><span><a href="#Open-Food-Facts" data-toc-modified-id="Open-Food-Facts-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Open Food Facts</a></span></li><li><span><a href="#Importations" data-toc-modified-id="Importations-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Importations</a></span></li><li><span><a href="#Fonctions" data-toc-modified-id="Fonctions-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Fonctions</a></span></li></ul></li><li><span><a href="#Exploration-des-données" data-toc-modified-id="Exploration-des-données-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploration des données</a></span><ul class="toc-item"><li><span><a href="#Chargement-des-données" data-toc-modified-id="Chargement-des-données-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Chargement des données</a></span></li><li><span><a href="#Taille-et-forme" data-toc-modified-id="Taille-et-forme-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Taille et forme</a></span></li><li><span><a href="#Nettoyage-de-base-sécurisé" data-toc-modified-id="Nettoyage-de-base-sécurisé-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Nettoyage de base sécurisé</a></span></li><li><span><a href="#Compréhension-des-données" data-toc-modified-id="Compréhension-des-données-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Compréhension des données</a></span><ul class="toc-item"><li><span><a href="#Identification-des-variables-d'objets" data-toc-modified-id="Identification-des-variables-d'objets-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Identification des variables d'objets</a></span></li><li><span><a href="#Aperçu-des-contributeurs" data-toc-modified-id="Aperçu-des-contributeurs-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Aperçu des contributeurs</a></span></li><li><span><a href="#Aperçu-du-moment-où-les-produits-ont-été-créés-par-les-contributeurs" data-toc-modified-id="Aperçu-du-moment-où-les-produits-ont-été-créés-par-les-contributeurs-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Aperçu du moment où les produits ont été créés par les contributeurs</a></span></li><li><span><a href="#Les-marques" data-toc-modified-id="Les-marques-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Les marques</a></span></li><li><span><a href="#Catégorie-principale" data-toc-modified-id="Catégorie-principale-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Catégorie principale</a></span></li><li><span><a href="#Identification-des-variables-numériques" data-toc-modified-id="Identification-des-variables-numériques-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>Identification des variables numériques</a></span></li></ul></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li><li><span><a href="#Nettoyage-des-données-en-surface" data-toc-modified-id="Nettoyage-des-données-en-surface-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Nettoyage des données en surface</a></span><ul class="toc-item"><li><span><a href="#Les-objets" data-toc-modified-id="Les-objets-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Les objets</a></span></li><li><span><a href="#Les-variables-numériques" data-toc-modified-id="Les-variables-numériques-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Les variables numériques</a></span></li><li><span><a href="#Filtrer-les-produits-disponible-en-France" data-toc-modified-id="Filtrer-les-produits-disponible-en-France-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>
4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Composition des macronutriments des aliments et énergie</a></span><ul class="toc-item"><li><span><a href="#Nettoyage-de-la-variable-PNNS-(Programme-National-Nutrition-Santé)" data-toc-modified-id="Nettoyage-de-la-variable-PNNS-(Programme-National-Nutrition-Santé)-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Nettoyage de la variable PNNS (Programme National Nutrition Santé)</a></span></li><li><span><a href="#Sélection-des-variables-et-des-observations" data-toc-modified-id="Sélection-des-variables-et-des-observations-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Sélection des variables et des observations</a></span></li><li><span><a href="#Suppression-des-produits-dont-les-valeurs-des-sous-ensembles-sont-incohérentes" data-toc-modified-id="Suppression-des-produits-dont-les-valeurs-des-sous-ensembles-sont-incohérentes-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Suppression des produits dont les valeurs des sous-ensembles sont incohérentes</a></span></li><li><span><a href="#Suppression-des-valeurs-aberrantes-par-groupes-de-PNNS" data-toc-modified-id="Suppression-des-valeurs-aberrantes-par-groupes-de-PNNS-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Suppression des valeurs aberrantes par groupes de PNNS</a></span></li><li><span><a href="#Statistiques-:-Macronutriments-par-groupes-de-PNNS" data-toc-modified-id="Statistiques-:-Macronutriments-par-groupes-de-PNNS-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Statistiques : Macronutriments par groupes de PNNS</a></span></li><li><span><a href="#Corrélation-entre-l'énergie-et-la-composition-en-macronutriments" data-toc-modified-id="Corrélation-entre-l'énergie-et-la-composition-en-macronutriments-4.3.6"><span class="toc-item-num">4.3.6&nbsp;&nbsp;</span>Corrélation entre l'énergie et la composition en macronutriments</a></span></li><li><span><a href="#Conclusion" data-toc-modified-id="Conclusion-4.3.7"><span class="toc-item-num">4.3.7&nbsp;&nbsp;</span>Conclusion</a></span></li></ul></li></ul></li><li><span><a href="#Exportation-des-données" data-toc-modified-id="Exportation-des-données-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Exportation des données</a></span></li><li><span><a href="#Transfert-vers-PostgreSQL" data-toc-modified-id="Transfert-vers-PostgreSQL-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Transfert vers PostgreSQL</a></span></li></ul></div>

# %% [markdown]
# # Introduction : Préparer des données pour un organisme de santé publique
#
# ## Santé publique France
#
# ![Santé Publique France](data/images/Sante-publique-France-logo.png)
#
# L'agence "Santé publique France" a lancé un appel à projets pour rendre les données de santé plus accessibles. L’agence souhaite faire explorer et visualiser des données, pour que ses agents puissent les exploiter.
#
#
# ## Open Food Facts
#
# ![Open Food Facts](data/images/OpenFoodFacts.png)
#
# À l’aide des données d’Open Food Facts, nous réaliserons une première exploration et visualisation des données, afin que les agents puissent ensuite s’appuyer sur nos résultats.

# %% [markdown]
# ## Importations
#
# Importation de bibliothèques et des paramètres.

# %%
from dotenv import load_dotenv
from IPython import get_ipython
from sqlalchemy import create_engine
import os
import json
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import psycopg2
import re
import requests
# Importer la méthode de régression linéaire depuis scipy.stats
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.linregress.html
from scipy.stats import linregress
# Importer la méthode du test t
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
from scipy.stats import ttest_ind
import scipy.stats as stats
import seaborn as sns
# https://scikit-learn.org/dev/modules/generated/sklearn.impute.KNNImputer.html
from sklearn.impute import KNNImputer
import warnings

# Afficher toutes les sorties de cellule
# from IPython.core.interactiveshell import InteractiveShell

# InteractiveShell.ast_node_interactivity = 'all'

# ipython = get_ipython()

# extension de chargement automatique
# if 'autoreload' not in ipython.extension_manager.loaded:
#     %load_ext autoreload

# %autoreload 2

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Fonctions
#
# Fonctions commune

# %%
# Calculer le nombre de lignes d'un dataframe spécifique
def get_rows(df):
    rows = df.shape[0]
    return rows


# Retourner les 10 premiers enregistrements par nom de colonne
def get_top_10(df, column_name):
    df_result = df.groupby([
        column_name
    ]).size().reset_index(name='Nombre').sort_values('Nombre',
                                                     ascending=False).head(10)

    rows = get_rows(df)
    df_result['Pourcentage'] = df_result['Nombre'] / rows * 100

    return df_result.copy()


# Compter le nombre de lignes vides pour un dataframe spécifique.
def get_empty_rows(df, column_name):
    return df.query(str(column_name) + '.isnull()').count()


# Afficher le graphique en barre avec le nombre
def show_plot(df, column_name):
    df_plot = df.loc[:, [column_name, 'Nombre']].set_index(
        column_name)['Nombre'].copy()

    plt.figure(figsize=(15, 10))

    sns.set(style="whitegrid")
    g = sns.barplot(df_plot, df_plot.index, orient='h')

    plt.title('Les plus grands ' + column_name, fontsize=20)
    plt.xlabel("Nombre d'occurrences", fontsize=14)
    plt.ylabel(column_name, fontsize=14)

    # Afficher le nombre à droite du graphique à barres
    for i, v in enumerate(df_plot.values.tolist()):
        g.text(v + 3, i + .25, str(v), color='black', fontweight='normal')

    plt.show()


# Imprimer les principaux éléments de statistiques
def print_stats(df, column_name):
    total_rows = get_rows(df)
    empty_rows = str(df[column_name].isna().sum())
    perc = int(empty_rows) * 100 / int(total_rows)
    print("Nombre d'enregistrements vides pour " + str(column_name) + ': ' +
          str(empty_rows) + ' (' + str(perc) + '%)')
    print(df[column_name].agg(['nunique', 'count', 'size']))

# %% [markdown]
# # Exploration des données
#
# Nous allons explorer les données afin de les comprendre.
#
# <div class="alert alert-warning">
# Veuillez noter que le fichier a été téléchargé depuis Internet et non depuis OpenClassRooms de manière à assurer la mise à jour et le suivi des données.</div>

# %% [markdown]
# ## Chargement des données

# %% [markdown]
# Chargement du jeu de données téléchargé à partir de https://static.openfoodfacts.org/data/fr.openfoodfacts.org.products.csv

# %%
# Chemin par défaut des données
data_path = 'data/'

# %%
# Lire le dossier
df = pd.read_csv(data_path + 'fr.openfoodfacts.org.products.csv',
                 sep="\t",
                 low_memory=False)

# %% [markdown]
# ## Taille et forme
#
# Nous aimerions vérifier la taille/forme des ensembles de données et comprendre quelles colonnes pourraient être utilisées pour les agents de Santé publique France. Identifier les lacunes, les NaN. D'une manière ou d'une autre, nous aimerions comprendre la qualité globale des données.

# %%
print('Open Food Facts contient ' + str(get_rows(df)) + ' produits et ' +
      str(df.shape[1]) + ' colonnes')
# Out:
# Open Food Facts contient 1741534 produits et 184 colonnes

# %% [markdown]
# Cet ensemble de données contient la valeur nutritive des aliments pour plus de 1 700 000 produits alimentaires provenant du monde entier.
#
# ![Open Food Facts](data/images/prince.jpg)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1741534 entries, 0 to 1741533
# Columns: 184 entries, code to carnitine_100g
# dtypes: float64(122), int64(2), object(60)
# memory usage: 2.4+ GB

# %%
df.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'abbreviated_product_name', 'generic_name',
#        ...
#        'carbon-footprint-from-meat-or-fish_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g', 'water-hardness_100g',
#        'choline_100g', 'phylloquinone_100g', 'beta-glucan_100g',
#        'inositol_100g', 'carnitine_100g'],
#       dtype='object', length=184)

# %%
df.dtypes.value_counts().plot.pie()
# Out:
# <AxesSubplot:ylabel='None'>

# %%
df.count()
# Out:
# code                  1741534
# url                   1741534
# creator               1741530
# created_t             1741534
# created_datetime      1741534
#                        ...
# choline_100g               41
# phylloquinone_100g       1712
# beta-glucan_100g           31
# inositol_100g              46
# carnitine_100g             20
# Length: 184, dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# code                                           0
# url                                            0
# created_t                                      0
# created_datetime                               0
# last_modified_t                                0
#                                           ...
# water-hardness_100g                      1741534
# no_nutriments                            1741534
# allergens_fr                             1741534
# cities                                   1741534
# ingredients_that_may_be_from_palm_oil    1741534
# Length: 184, dtype: int64

# %%
df.isnull().sum().plot(kind='hist', figsize=(15, 10))
plt.title('Distribution de NaNs')
plt.xlabel('NaNs')

plt.show()

# %% [markdown]
# ## Nettoyage de base sécurisé

# %% [markdown]
# Nous pouvons en toute sécurité supprimer les lignes (individus) et les colonnes (variables) sans données ou doublons s'il y en a.

# %%
nrows, ncols = df.shape

# Supprimer les lignes sans données.
df.dropna(how='all', inplace=True)

# Supprimer les colonnes sans données.
empty_variables = df.columns[df.isnull().sum() == df.shape[0]]
df.dropna(how='all', axis=1, inplace=True)

# Supprimer les valeurs en double
duplicates_count = df.duplicated().sum()
df.drop_duplicates(inplace=True)

print("Nombre de lignes vides supprimées: {}".format(nrows - df.shape[0]))
print('Nombre de colonnes vides supprimées: {}'.format(len(empty_variables)))
print('Colonnes supprimées:\n{}'.format(empty_variables))
print('Nombre de doublons supprimés: {}'.format(duplicates_count))
print('\nDimensions du jeu de données: {}'.format(df.shape))
# Out:
# Nombre de lignes vides supprimées: 1
# Nombre de colonnes vides supprimées: 6
# Colonnes supprimées:
# Index(['cities', 'allergens_fr', 'no_nutriments', 'ingredients_from_palm_oil',
#        'ingredients_that_may_be_from_palm_oil', 'water-hardness_100g'],
#       dtype='object')
# Nombre de doublons supprimés: 1
#
# Dimensions du jeu de données: (1741533, 178)

# %% [markdown]
# ## Compréhension des données
#
# Le but de cette partie est de comprendre les données fournies par Open Food Facts. Nous aimerions comprendre l'exhaustivité et la fiabilité de ces données.
#
# (https://fr.openfoodfacts.org/guide-pour-les-producteurs)
#
# 1. Identification des variables d'objets :
# Nous souhaitons comprendre les variables qualitatives à travers un jeu d'exploration.
#
# 1. Qui sont les contributeurs :
# Nous aimerions vérifier qui sont les contributeurs, qui contribue le plus, si nous pouvons faire confiance à la source et si nous pouvons trouver des références sur le net.
#
# 3. Quelles sont les marques :
# Nous voulons vérifier si tous les produits sont assignés à une marque et si toutes ces marques existent (vérification croisée avec wikipedia par exemple).
#
# 4.  Quelles sont les catégories principales :
# Nous cherchons à savoir quelles sont les catégories principales (nombre/pourcentage/NaNs).
#
# 5. Identification des variables numérique :
# Nous souhaitons comprendre les variables quantitatives à travers un jeu d'exploration.

# %% [markdown]
# ### Identification des variables d'objets

# %% [markdown]
# Ayons un meilleur aperçu de l'ensemble de données. Parce qu'il y a beaucoup de variables, nous traiterons séparément les variables objet et numériques.

# %%
# Augmenter le nombre de lignes par défaut affichées par pandas
pd.set_option('max_rows', 178)

# Obtenir un résumé pour les variables d'objet seulement
df.describe(include='object').T
# Out:
#                                               count   unique  \
# code                                        1741533  1741530
# url                                         1741533  1741530
# creator                                     1741529    13382
# created_datetime                            1741533  1492133
# last_modified_datetime                      1741533  1368983
# product_name                                1664013  1095758
# abbreviated_product_name                       3223     3192
# generic_name                                 113017    82309
# quantity                                     453621    35265
# packaging                                    280313    50396
# packaging_tags                               280286    41091
# packaging_text                                 3475     2183
# brands                                       908763   160641
# brands_tags                                  908707   124707
# categories                                   835574    87767
# categories_tags                              835574    63018
# categories_fr                                835574    63007
# origins                                       75533    12389
# origins_tags                                  75413    10116
# origins_fr                                    75413    10095
# manufacturing_places                         111687    25937
# manufacturing_places_tags                    111636    23358
# labels                                       386278    77154
# labels_tags                                  386299    55547
# labels_fr                                    386299    55457
# emb_codes                                    112130    30988
# emb_codes_tags                               112100    27030
# first_packaging_code_geo                      69082     3628
# cities_tags                                   74466     6784
# purchase_places                              150525    10790
# stores                                       218181    14016
# countries                                   1736055    10210
# countries_tags                              1736051     4007
# countries_fr                                1736051     4005
# ingredients_text                             685542   575726
# allergens                                    181085     6609
# traces                                        93386    11276
# traces_tags                                  116159    11340
# traces_fr                                    116159    11340
# serving_size                                 465908    45577
# additives                                         5        5
# additives_tags                               397342    93683
# additives_fr                                 397342    93683
# ingredients_from_palm_oil_tags                13964       16
# ingredients_that_may_be_from_palm_oil_tags    40092      333
# nutriscore_grade                             650486        5
# pnns_groups_1                               1725153       14
# pnns_groups_2                               1741296       46
# states                                      1741533     5509
# states_tags                                 1741533     5509
# states_fr                                   1741533     4387
# brand_owner                                  289443    25562
# main_category                                835574    28858
# main_category_fr                             835574    28838
# image_url                                   1307385  1307219
# image_small_url                             1307385  1307219
# image_ingredients_url                        677919   677881
# image_ingredients_small_url                  677919   677881
# image_nutrition_url                          847203   847169
# image_nutrition_small_url                    847203   847169
#
#                                                                                           top  \
# code                                                                            7798049540559
# url                                         http://world-fr.openfoodfacts.org/produit/3038...
# creator                                                                               kiliweb
# created_datetime                                                         2020-04-23T17:22:07Z
# last_modified_datetime                                                   2021-02-27T09:03:05Z
# product_name                                                     Aceite de oliva virgen extra
# abbreviated_product_name                                                 6x27,5cl tourtel twi
# generic_name                                         Pâtes alimentaires de qualité supérieure
# quantity                                                                                500 g
# packaging                                                                          Kunststoff
# packaging_tags                                                               sachet,plastique
# packaging_text                                                               Bouteille, verre
# brands                                                                              Carrefour
# brands_tags                                                                         carrefour
# categories                                                                             Snacks
# categories_tags                                                                     en:snacks
# categories_fr                                                                          Snacks
# origins                                                                                France
# origins_tags                                                                        en:france
# origins_fr                                                                             France
# manufacturing_places                                                                   France
# manufacturing_places_tags                                                              france
# labels                                                                                Organic
# labels_tags                                                                        en:organic
# labels_fr                                                                                 Bio
# emb_codes                                                                         FSC-C014047
# emb_codes_tags                                                                    fsc-c014047
# first_packaging_code_geo                                                  47.833333,-0.333333
# cities_tags                                                    sable-sur-sarthe-sarthe-france
# purchase_places                                                                        France
# stores                                                                              Carrefour
# countries                                                                              France
# countries_tags                                                                      en:france
# countries_fr                                                                           France
# ingredients_text                                            Carbonated water, natural flavor.
# allergens                                                                             en:milk
# traces                                                                                en:nuts
# traces_tags                                                                           en:nuts
# traces_fr                                                                      Fruits à coque
# serving_size                                                                     1 ONZ (28 g)
# additives                                    [ almedra -> es:almedra  ]  [ 40 -> es:40  ] ...
# additives_tags                                                                        en:e330
# additives_fr                                                            E330 - Acide citrique
# ingredients_from_palm_oil_tags                                                 huile-de-palme
# ingredients_that_may_be_from_palm_oil_tags                                e160a-beta-carotene
# nutriscore_grade                                                                            d
# pnns_groups_1                                                                         unknown
# pnns_groups_2                                                                         unknown
# states                                      en:to-be-completed, en:nutrition-facts-complet...
# states_tags                                 en:to-be-completed,en:nutrition-facts-complete...
# states_fr                                   À compléter,Informations nutritionnelles compl...
# brand_owner                                                             Wal-Mart Stores, Inc.
# main_category                                                                       en:snacks
# main_category_fr                                                                       Snacks
# image_url                                   https://static.openfoodfacts.org/images/produc...
# image_small_url                             https://static.openfoodfacts.org/images/produc...
# image_ingredients_url                       https://static.openfoodfacts.org/images/produc...
# image_ingredients_small_url                 https://static.openfoodfacts.org/images/produc...
# image_nutrition_url                         https://static.openfoodfacts.org/images/produc...
# image_nutrition_small_url                   https://static.openfoodfacts.org/images/produc...
#
#                                                freq
# code                                              2
# url                                               2
# creator                                      974818
# created_datetime                                 28
# last_modified_datetime                          145
# product_name                                   1243
# abbreviated_product_name                          7
# generic_name                                    283
# quantity                                      19622
# packaging                                      6369
# packaging_tags                                 9084
# packaging_text                                   91
# brands                                        14320
# brands_tags                                   15065
# categories                                    32705
# categories_tags                               32877
# categories_fr                                 32877
# origins                                       18902
# origins_tags                                  19474
# origins_fr                                    19481
# manufacturing_places                          23433
# manufacturing_places_tags                     24469
# labels                                        23828
# labels_tags                                   46412
# labels_fr                                     46412
# emb_codes                                      1334
# emb_codes_tags                                 1345
# first_packaging_code_geo                       1190
# cities_tags                                     946
# purchase_places                               41707
# stores                                        16614
# countries                                    428649
# countries_tags                               719896
# countries_fr                                 719896
# ingredients_text                                475
# allergens                                     38409
# traces                                         8726
# traces_tags                                   11614
# traces_fr                                     11614
# serving_size                                  19881
# additives                                         1
# additives_tags                                24955
# additives_fr                                  24955
# ingredients_from_palm_oil_tags                13240
# ingredients_that_may_be_from_palm_oil_tags    10657
# nutriscore_grade                             202357
# pnns_groups_1                               1063215
# pnns_groups_2                               1063215
# states                                       177754
# states_tags                                  177754
# states_fr                                    177754
# brand_owner                                    5389
# main_category                                 32884
# main_category_fr                              32884
# image_url                                        56
# image_small_url                                  56
# image_ingredients_url                            10
# image_ingredients_small_url                      10
# image_nutrition_url                               7
# image_nutrition_small_url                         7

# %% [markdown]
# Nous pouvons remarquer que :
#
# - Pour rappel, nous avons 1 741 534 lignes, cela signifie donc que nous avons beaucoup de valeurs manquantes dans nos données.
# - Les colonnes `code` (code barre) ou `url` peuvent être utilisées comme _clé/index unique_. Nous devons également éliminer les lignes dont le code est manquant ou double.
# - Le `creator` le plus fréquent est _kiliweb_. Nous enquêterons dessus plus tards. Avec ses  13 382 `creator`, cet ensemble de données est probablement une agrégation de plusieurs sources de données avec leur propre structure, ce qui pourrait expliquer pourquoi l'ensemble de données semble très clairsemé.
# - Nous avons des informations temporelles. `created_datetime` et `last_modified_datetime` doivent être converties vers le type `datetime`.
# - Les variables sont souvent déclinées en trois versions : `x`(ex.: categories), `x_lang` (ex.: categories_fr), `x_tags` (ex.: categories_tags).
# Notons le préfixe `en:` (ex.: en:france), cela signifie que nous avons probablement plusieurs langues dans les données.
# - Les variables `states` et `states_fr` donnent quelques informations sur l'état d'avancement de chaque observation.
#
# Nous pouvons également identifier quelques thèmes :
#
# - Origine, Marques, Etiquettes, Pays
# - Emballage, Code Emb, Lieux de fabrication
# - Ingrédients, Allergènes, Traces, Additifs
# - Huile de palme
#
# Et quelques variables de classification intéressantes :
#
# - `categories, main_category`
# - `pnns_groups`
# - `nutriscore_grade` (pourrait être une variable cible pour construire un modèle)

# %% [markdown]
# ### Aperçu des contributeurs

# %%
# Obtenir les 10 premiers contributeurs
df_10_contributors = get_top_10(df, 'creator')

# Afficher le résultat
print('\nLes 10 premiers contributeurs (en nombre et en pourcentage)')
print(df_10_contributors)
show_plot(df_10_contributors, 'creator')

# Afficher des informations sur les observations vides
print_stats(df, 'creator')
# Out:
# Les 10 premiers contributeurs (en nombre et en pourcentage)
#                           creator  Nombre  Pourcentage
# 6594                      kiliweb  974818    55.974707
# 12530             usda-ndb-import  169827     9.751581
# 9512   openfoodfacts-contributors  162061     9.305652
# 9558            org-database-usda  134539     7.725320
# 3574                       elcoco   33179     1.905161
# 2920              date-limite-app   31189     1.790893
# 5440                          inf   11513     0.661084
# 9510           openfood-ch-import   11455     0.657754
# 11138                    sebleouf   10309     0.591950
# 10218                  prepperapp    9964     0.572140
# Nombre d'enregistrements vides pour creator: 4 (0.00022968269909327013%)
# nunique      13382
# count      1741529
# size       1741533
# Name: creator, dtype: int64

# %% [markdown]
# Après avoir chargé et explorer légèrement les nous pouvons commencer à identifier qui sont les contributeurs : https://fr.openfoodfacts.org/contributeurs
#
# Pouvons-nous leur faire confiance ?
#
# Une grande partie des données a été générée par kiliweb. Approximativement 55%. Qui est-ce ?
#
# Kiliweb semble être une agence web en France. Une grande moitié des données est fourni par cette agence. Il serait préférable d'enquêter dessus dans la partie analyse.

# %% [markdown]
# ### Aperçu du moment où les produits ont été créés par les contributeurs

# %%
top_5_creators = df.loc[(df['creator'] == 'kiliweb') |
                        (df['creator'] == 'usda-ndb-import') |
                        (df['creator'] == 'openfoodfacts-contributors') |
                        (df['creator'] == 'org-database-usda') |
                        (df['creator'] == 'elcoco')][[
                            'creator', 'created_datetime'
                        ]]

top_5_creators['mod_datetime'] = top_5_creators['created_datetime'].apply(
    lambda x: x[0:4])
top_5_creators.drop('created_datetime', axis=1)

mod_pivot = pd.pivot_table(top_5_creators,
                           index=top_5_creators['mod_datetime'],
                           columns='creator',
                           aggfunc=len,
                           fill_value=0)
mod_pivot.plot(kind="line",
               figsize=(12, 8),
               title="Quand les produits ont-ils été créés ?")
mod_pivot.plot(kind="bar",
               figsize=(12, 8),
               title="Quand les produits ont-ils été créés ?")
# Out:
# <AxesSubplot:title={'center':'Quand les produits ont-ils été créés ?'}, xlabel='mod_datetime'>

# %% [markdown]
# Jusqu'à présent, nous pouvons voir que Kiliweb est le contributeur le plus actif et ajoute continuellement des produits. C'est le contributeur le plus actif. La plupart des produits sont donc probablement principalement de France.
# Nous pouvons déjà supposer, sur la base des principaux contributeurs, que les produits français prédominent.
#
# usda-ndb-import, qui est le 'United States Department of Agriculture' semble ne plus contribuer à la base de données open food facts et n'a été importé qu'une seule fois.
#
# La communauté ouverte des contributeurs d'openfoodfacts semble s'agrandir au fil des années. La diversité des contributeurs peut conduire à des données non concordantes.

# %% [markdown]
# ### Les marques
# Informations générales sur les marques

# %%
# Obtenir le top 10 des marques
df_10_brands = get_top_10(df, 'brands')

# Afficher le résultat
print('\nLes 10 premières marques (nombres et pourcentages)')
print(df_10_brands)
show_plot(df_10_brands, 'brands')

# Afficher des informations sur les enregistrements vides
print_stats(df, 'brands')
# Out:
# Les 10 premières marques (nombres et pourcentages)
#               brands  Nombre  Pourcentage
# 20495      Carrefour   14320     0.822264
# 7410          Auchan   11241     0.645466
# 15064        Bonarea    6960     0.399648
# 127017             U    6185     0.355147
# 31793       Delhaize    4995     0.286816
# 52197      Hacendado    4904     0.281591
# 21246         Casino    4502     0.258508
# 90856         Nestlé    4340     0.249206
# 71810   Leader Price    4204     0.241397
# 27020           Coop    3469     0.199192
# Nombre d'enregistrements vides pour brands: 832770 (47.81821533097564%)
# nunique     160641
# count       908763
# size       1741533
# Name: brands, dtype: int64

# %% [markdown]
# 48% des produits ne sont associés à aucune marque. En outre, les 6 plus grandes marques d'Open Food Facts sont Français.
#
# Il semble que, comme décrit ci-dessus avec les contributeurs, la communauté française, à travers kiliweb, est le contributeur le plus important. Cela peut expliquer pourquoi il y a tant de produits assignés à la France.

# %%
# Obtenir le top 10 de countries_fr
df_10_countries_fr = get_top_10(df, 'countries_fr')

# Afficher le résultat
print('\nTop 10 countries (Counts & Percentage)')
print(df_10_countries_fr)
show_plot(df_10_countries_fr, 'countries_fr')

# Afficher des informations sur les NaNs
print_stats(df, 'countries_fr')
# Out:
# Top 10 countries (Counts & Percentage)
#           countries_fr  Nombre  Pourcentage
# 2215            France  719896    41.336914
# 3987        États-Unis  343086    19.700230
# 2092           Espagne  196916    11.307050
# 3193            Italie   61439     3.527869
# 123          Allemagne   59186     3.398500
# 972           Belgique   47760     2.742411
# 3758            Suisse   45303     2.601329
# 3557       Royaume-Uni   38649     2.219252
# 1741            Canada   27515     1.579930
# 2219  France,Allemagne   11781     0.676473
# Nombre d'enregistrements vides pour countries_fr: 5482 (0.3147801391073267%)
# nunique       4005
# count      1736051
# size       1741533
# Name: countries_fr, dtype: int64

# %% [markdown]
# Nous découvrons ici le même comportement que l'analyse précédente. La plupart des produits sont attribués à la France, ce qui était attendu puisque le principal contributeur est kiliweb une agence web française. Ceci est cohérent, surtout après l'analyse des contributeurs et des marques ci-dessus.
#
# Même si la plupart des produits ont été assignés à un pays, 5482 produits ne sont liés à aucun pays et qu'il y a 4005 pays.
#
# Jusqu'à présent, il semble que les pays contiennent une liste de pays et non un pays unique comme en témoigne la 10e ligne "France,Allemagne".
#
# De plus, la plupart des produits sont liés à un ou deux pays seulement, ce qui est très suspect. Nous pourrions par exemple supposer sans le moindre doute que cette confiture à la fraise de l'Oregon https://fr.openfoodfacts.org/produit/0011110901422/oregonstrawberry-kroger attribué à la France a été fondée aux USA puisque c'est là où se situe l'Oregon et qu'il est fabriqué par Kroger https://fr.wikipedia.org/wiki/Kroger.
#
# <img src="https://static.openfoodfacts.org/images/products/001/111/090/1422/front_fr.4.full.jpg"></img>
#
# Très probablement, ce produit est vendu en France et a été répertorié comme produit français. Mais nous pouvons être sûrs que cette confiture est également vendu aux Etats-Unis, peut-être sous un autre nom de produit.
#
# Jusqu'à présent, nous pouvons conclure que ce champ pays doit être utilisé avec précaution pour fournir une analyse de produits français ou vendu en France aux agents de Santé Publique France.

# %%
# Obtenir le top 10 des origines
df_10_origins = get_top_10(df, 'origins')

# Afficher le résultat
print('\nTop 10 des origines (nombres et pourcentages)')
print(df_10_origins)
show_plot(df_10_origins, 'origins')

# Afficher des informations sur les enregistrements vides
print_stats(df, 'origins')
# Out:
# Top 10 des origines (nombres et pourcentages)
#                origins  Nombre  Pourcentage
# 3267            France   18902     1.085366
# 6058            México    1886     0.108295
# 8875  Union Européenne    1603     0.092045
# 2709            España    1450     0.083260
# 4877            Italie    1332     0.076484
# 2638           Espagne    1242     0.071316
# 2235       Deutschland    1076     0.061785
# 8951  Union européenne     988     0.056732
# 4989             Italy     809     0.046453
# 4848            Italia     807     0.046338
# Nombre d'enregistrements vides pour origins: 1666000 (95.66284417234701%)
# nunique      12389
# count        75533
# size       1741533
# Name: origins, dtype: int64

# %% [markdown]
# Les origines sont très dénormalisées et peuvent contenir comme valeur un pays une région ou un continent,... 12389 valeurs uniques, c'est beaucoup plus que la liste des pays potentiels.
#
# Cela rend l'utilisation de ce champ difficile.

# %% [markdown]
# ### Catégorie principale

# %% [markdown]
# Nous cherchons à savoir quelles sont les principales catégories (nombre/pourcentage/NaNs).

# %%
# Obtenir le top 10 Catégorie principale
df_10_main_category_fr = get_top_10(df, 'main_category_fr')

# Show Result
print('\nTop 10 des principales catégories (nombres et pourcentages)')
print(df_10_main_category_fr)
show_plot(df_10_main_category_fr, 'main_category_fr')

# Afficher des informations sur les enregistrements vides
print_stats(df, 'main_category_fr')
# Out:
# Top 10 des principales catégories (nombres et pourcentages)
#           main_category_fr  Nombre  Pourcentage
# 13764               Snacks   32884     1.888221
# 13040               Sauces   16013     0.919477
# 3575           Confiseries   15262     0.876354
# 5866              Fromages   14652     0.841328
# 1142              Biscuits   14638     0.840524
# 1609              Boissons    9314     0.534816
# 4665       Desserts glacés    9238     0.530452
# 9838                 Pains    8999     0.516729
# 22489     en:salted-snacks    7684     0.441220
# 4467   Céréales et dérivés    7402     0.425028
# Nombre d'enregistrements vides pour main_category_fr: 905959 (52.020777096959975%)
# nunique      28838
# count       835574
# size       1741533
# Name: main_category_fr, dtype: int64

# %% [markdown]
# Il semble que 52% des produits n'ont pas de catégorie.

# %% [markdown]
# ### Identification des variables numériques

# %%
# Obtenir une liste pour les variables numériques uniquement
df.describe(include='number').T
# Out:
#                                              count          mean  \
# created_t                                1741533.0  1.550696e+09
# last_modified_t                          1741533.0  1.585857e+09
# serving_quantity                          460930.0  2.410585e+16
# additives_n                               685544.0  2.046187e+00
# ingredients_from_palm_oil_n               685544.0  2.062596e-02
# ingredients_that_may_be_from_palm_oil_n   685544.0  6.907799e-02
# nutriscore_score                          650486.0  9.182527e+00
# nova_group                                599607.0  3.431875e+00
# energy-kj_100g                            126273.0  5.278689e+37
# energy-kcal_100g                         1329062.0  6.541628e+06
# energy_100g                              1383076.0  4.819373e+36
# energy-from-fat_100g                         976.0  3.626456e+02
# fat_100g                                 1374956.0  1.459658e+01
# saturated-fat_100g                       1331639.0  1.267818e+01
# butyric-acid_100g                             12.0  6.456205e+19
# caproic-acid_100g                              3.0  1.613000e+01
# caprylic-acid_100g                             3.0  4.313333e+01
# capric-acid_100g                               9.0  9.656407e+54
# lauric-acid_100g                              15.0  2.152893e+01
# myristic-acid_100g                             5.0  3.787602e+01
# palmitic-acid_100g                            18.0  1.415243e+02
# stearic-acid_100g                              7.0  6.147114e+01
# arachidic-acid_100g                           76.0  1.099256e+01
# behenic-acid_100g                             28.0  1.679387e+00
# lignoceric-acid_100g                           2.0  2.082500e-03
# cerotic-acid_100g                              7.0  3.142939e+00
# montanic-acid_100g                            13.0  4.191668e+01
# melissic-acid_100g                             8.0  3.515514e-01
# monounsaturated-fat_100g                   47384.0  9.918998e+00
# polyunsaturated-fat_100g                   47383.0  5.894638e+00
# omega-3-fat_100g                            1971.0  1.922330e+01
# alpha-linolenic-acid_100g                    463.0  2.893993e+00
# eicosapentaenoic-acid_100g                   117.0  1.557723e+00
# docosahexaenoic-acid_100g                    165.0  8.802960e-01
# omega-6-fat_100g                             500.0  3.188429e+01
# linoleic-acid_100g                           233.0  4.496813e+00
# arachidonic-acid_100g                         71.0  2.401500e+00
# gamma-linolenic-acid_100g                      9.0  2.132878e+00
# biotin_100g                              4.200000e-05  1.000000e+02
# pantothenic-acid_100g                    4.000000e-03  5.000000e+01
# silica_100g                              1.595000e-02  1.500000e+02
# bicarbonate_100g                         2.060000e-01  2.470000e+02
# potassium_100g                           3.000000e-01  8.750000e+02
# chloride_100g                            5.675000e-02  5.000000e+01
# calcium_100g                             1.100000e-01  9.300000e+02
# phosphorus_100g                          3.330000e-01  6.500000e+02
# iron_100g                                2.410000e-03  1.200000e+02
# magnesium_100g                           1.330000e-01  4.440000e+04
# zinc_100g                                5.770000e-03  4.000000e+01
# copper_100g                              1.071000e-03  6.900000e+01
# manganese_100g                           2.000000e-03  5.600000e+00
# fluoride_100g                            4.500000e-04  1.700000e+01
# selenium_100g                            4.700000e-05  3.880000e+01
# chromium_100g                            6.287500e-05  9.900000e+01
# molybdenum_100g                          5.085000e-05  3.800000e+01
# iodine_100g                              8.700000e-05  2.500000e+03
# caffeine_100g                            4.600000e-02  5.000000e+02
# taurine_100g                             4.000000e-01  4.000000e+02
# ph_100g                                  7.510000e+00  1.400000e+01
# fruits-vegetables-nuts_100g              6.000000e+01  1.000000e+02
# fruits-vegetables-nuts-dried_100g        2.625000e+01  1.000000e+02
# fruits-vegetables-nuts-estimate_100g     6.400000e+01  1.000000e+02
# collagen-meat-protein-ratio_100g         1.500000e+01  1.000000e+02
# cocoa_100g                               7.000000e+01  1.000000e+02
# chlorophyl_100g                          1.590000e+00  2.183000e+00
# carbon-footprint_100g                    2.797500e+02  1.386700e+04
# carbon-footprint-from-meat-or-fish_100g  6.142000e+02  6.562986e+05
# nutrition-score-fr_100g                  1.600000e+01  4.000000e+01
# nutrition-score-uk_100g                  2.200000e+01  2.500000e+01
# glycemic-index_100g                      4.517500e+01  4.870000e+01
# choline_100g                             1.000000e-01  6.210000e+01
# phylloquinone_100g                       9.600000e-05  5.400000e+01
# beta-glucan_100g                         4.000000e+00  7.300000e+00
# inositol_100g                            2.720000e-02  1.500000e-01
# carnitine_100g                           1.125000e-02  5.720000e-01

# %% [markdown]
# Nous pouvons identifier quelques thèmes :
#
# - Les macronutriments avec leurs multiples niveaux de décomposition : glucides, lipides, protéines.
# - les micronutriments : minéraux, vitamines
# - Le score énergétique et nutritionnel (qui pourrait être utilisé comme variable cible pour construire un modèle).
#
# Nous pouvons également remarquer que :
#
# - Nous avons très peu de données pour les niveaux de décomposition. Nous pourrions probablement abandonner toutes ces variables ou les conserver malgré tout pour mener une étude approfondie sur les carences.
# - Les données sont normalisées sur 100 grammes. Il y a quelques valeurs négatives et des valeurs supérieures à 100 à nettoyer.
# - Le score nutritionnel va de -15 à 40 (cela semble d’après le site santé publique)
# - L’énergie est exprimée en kilojoules.

# %% [markdown]
# ## Conclusion
#
# Après avoir compris en surface le jeu de données, nous pouvons supprimer les observations dont les valeurs sont incohérentes. Nous pourrions décider de remplacer les valeurs négatives par 0, étant donné la nature du projet, les observations avec des données incohérentes sont probablement de mauvaises entrées et nous avons aussi plus que suffisamment de données.

# %% [markdown]
# # Nettoyage des données en surface

# %% [markdown]
# Cette partie, contient toutes les activités de nettoyage des données, effectuées sur le fichier fr.openfoodfacts.org.products.csv. Le but de cette partie est de nettoyer les données et de les enrichir en fonction des activités requises. Qui est, pour rappel, fournir des données de santé plus accessible pour les agents de santé publique.
#
# Avant d'effectuer toute analyse, il est en effet important de disposer d'un ensemble de données consolidées correctes. En effet, nous découvrons que l'ensemble de données nécessite beaucoup d'activités de nettoyage et que la qualité des données est parfois médiocre.

# %% [markdown]
# ## Les objets
# Nettoyons les données comme indiqué ci-dessus. Nous restons très conservateurs.

# %%
# Définir le sous-ensemble de variables dans lequel
# nous ne voulons pas de données manquantes.
subset = [
    'code', 'creator', 'created_datetime', 'last_modified_datetime',
    'product_name', 'states_tags'
]

# Supprimer les lignes avec
# des données manquantes dans ce sous-ensemble.
df.dropna(subset=subset, inplace=True)

# Supprimer les nouvelles variables avec des données
# manquantes qui apparaissent après la suppression précédente.
df.dropna(how='all', axis=1, inplace=True)

print('Forme du jeu de données: {}'.format(df.shape))
# Out:
# Forme du jeu de données: (1664009, 178)

# %% [markdown]
# Réduction du nombre de lignes à 1 664 003.

# %% [markdown]
# Nous cherchons à savoir s'il y a d'autres anomalies dans les données. Nous examinons la qualité des données pour comprendre ce qui pourrait être utilisé pour une analyse plus approfondie.

# %% [markdown]
# Nous avons identifié quelques doublons comme indiqué ci-dessus, qui devraient être nettoyés/supprimés, une fois clairement identifiés.

# %%
df[df.duplicated(subset='code')].head()
# Out:
#                    code                                                url  \
# 633814   30383354190402  http://world-fr.openfoodfacts.org/produit/3038...
# 1015382   3770008983205  http://world-fr.openfoodfacts.org/produit/3770...
# 1389391   7798049540559  http://world-fr.openfoodfacts.org/produit/7798...
#
#                             creator   created_t      created_datetime  \
# 633814   openfoodfacts-contributors  1608035756  2020-12-15T12:35:56Z
# 1015382                         r-x  1614201389  2021-02-24T21:16:29Z
# 1389391  openfoodfacts-contributors  1615222625  2021-03-08T16:57:05Z
#
#          last_modified_t last_modified_datetime           product_name  \
# 633814        1610702583   2021-01-15T09:23:03Z                basilic
# 1015382       1614242412   2021-02-25T08:40:12Z  REMYX VODKA Aquatique
# 1389391       1615337611   2021-03-10T00:53:31Z               lentejas
#
#         abbreviated_product_name generic_name  ... carbon-footprint_100g  \
# 633814                       NaN          NaN  ...                   NaN
# 1015382                      NaN        Vodka  ...                   NaN
# 1389391                      NaN          NaN  ...                   NaN
#
#         carbon-footprint-from-meat-or-fish_100g nutrition-score-fr_100g  \
# 633814                                      NaN                    -3.0
# 1015382                                     NaN                     NaN
# 1389391                                     NaN                     NaN
#
#         nutrition-score-uk_100g glycemic-index_100g choline_100g  \
# 633814                      NaN                 NaN          NaN
# 1015382                     NaN                 NaN          NaN
# 1389391                     NaN                 NaN          NaN
#
#         phylloquinone_100g beta-glucan_100g inositol_100g carnitine_100g
# 633814                 NaN              NaN           NaN            NaN
# 1015382                NaN              NaN           NaN            NaN
# 1389391                NaN              NaN           NaN            NaN
#
# [3 rows x 178 columns]

# %%
# Suppression des doublons dans la colonne code
df.drop_duplicates('code', keep=False, inplace=True)

# %%
# Définir code comme index
df.set_index('code', inplace=True)

# %%
# Convertir les variables d'objet created_datetime
# et last_modified_datetime en variables de type datetime.
df.created_datetime = pd.to_datetime(df.created_datetime)
df.last_modified_datetime = pd.to_datetime(df.last_modified_datetime)

df.created_datetime.head()
# Out:
# code
# 0000000000017          2018-06-15 10:38:00+00:00
# 0000000000031          2018-10-13 21:06:14+00:00
# 000000000003327986     2019-11-19 15:02:16+00:00
# 0000000000100          2015-10-11 14:09:21+00:00
# 00000000001111111111   2019-06-08 18:56:13+00:00
# Name: created_datetime, dtype: datetime64[ns, UTC]

# %% [markdown]
# ## Les variables numériques
# Nettoyons les données comme indiqué ci-dessus.

# %% [markdown]
# Nous allons maintenant éliminer toutes les lignes, qui contiennent des valeurs impossibles par définition.

# %% [markdown]
# Une inspection des valeurs min et max révèle qu'il y a des erreurs évidentes dans nos données.

# %%
# Supprimer les observations dont les
# éléments x_100g ont des valeurs négatives
obs_with_negative_facts = (df.loc[:, 'fat_100g':'chlorophyl_100g'] < 0).any(
    axis=1)
df.drop(df[obs_with_negative_facts].index, inplace=True)

# Supprimer les observations x_100g qui ont une valeur supérieure à 100g
obs_with_facts_over_100 = (df.loc[:, 'fat_100g':'chlorophyl_100g'] > 100).any(
    axis=1)
df.drop(df[obs_with_facts_over_100].index, inplace=True)

# Supprimer les observations dont la somme de
# lipide + glucide + protéine ont une valeur supérieure à 100g
df[(df['fat_100g'] + df['carbohydrates_100g'] + df['proteins_100g']) <= 100]

print('Produit avec la valeur minimale: {}'.format(
    df.describe(include='number').T.loc['fat_100g':'cocoa_100g', 'min'].min()))
print('Produit avec la valeur maximale: {}'.format(
    df.describe(include='number').T.loc['fat_100g':'cocoa_100g', 'max'].max()))
print('Forme du jeu de données: {}'.format(df.shape))
# Out:
# Produit avec la valeur minimale: 0.0
# Produit avec la valeur maximale: 100.0
# Forme du jeu de données: (1662721, 177)

# %% [markdown]
# Au cours de ce processus, nous avons abandonné 761 365 observations.

# %% [markdown]
# ## Filtrer les produits disponible en France

# %%
# TODO : Améliorer le script
countries_filter = df['countries_tags'].astype(dtype='str').str.split(',')
df_fr = df[countries_filter.apply(lambda lang: 'en:france' in lang)]
df_fr.shape
# Out:
# (769290, 177)

# %% [markdown]
# Dans cette dataframe nous abandonnons 480 374 observations.

# %% [markdown]
# ## Les valeurs manquantes

# %% [markdown]
# Regardons plus en détail les valeurs manquantes, l'ensemble de données est très clairsemé mais nous allons en avoir un meilleur aperçu en traçant un histrogramme du pourcentage de valeurs manquantes par variables, empilées par type (objet et nombre) et aussi un histrogramme du pourcentage de valeurs manquantes par observation.

# %%
# Distribution des valeurs manquantes par variable,
# empilées par type de variable
nan_counts_object_vars = df_fr.select_dtypes(
    'object').isnull().sum() / df_fr.shape[0] * 100
nan_counts_number_vars = df_fr.select_dtypes(
    'number').isnull().sum() / df_fr.shape[0] * 100

pd.DataFrame({'object': nan_counts_object_vars, 'number': nan_counts_number_vars}) \
  .plot.hist(stacked=True, bins=20, figsize=(12, 6))

plt.xlabel('Pourcentage de valeurs NaN')
plt.ylabel('# Variable')
plt.title(
    'Distribution des valeurs NaN par variable, empilées par type de variable')
plt.show()

# %% [markdown]
# Il est clair que nous avons des variables avec des valeurs essentiellement manquantes mais nous devons nous demander ce que signifie avoir des valeurs manquantes dans une variable objet et une variable numérique du point de vue du domaine :
#
# - Les variables objet sont essentiellement des données qui décrivent les produits ou permettent de les classer. À un haut niveau, les valeurs manquantes signifient que la fiche produit est incomplète. Par exemple, si nous sommes intéressés par les groupes de produits, nous travaillerons au mieux avec environ 1/3 de l'ensemble de données.
#
# - La plupart des variables numériques sont des faits alimentaires. Certains faits sont simplement moins actuels que d'autres ; s'il est presque impossible de trouver un produit sans indication sur les graisses, il sera plus difficile d'en trouver un avec du fer par exemple. Étant donné que l'ensemble de données présente les informations sur les aliments sous une forme non empilée, nous disposons de données très éparses. Dans ce cas, les variables présentant un grand nombre de valeurs manquantes ne sont pas synonymes de mauvaises variables, bien au contraire. Si nous voulions analyser les aliments pour bébés à différents âges, ces faits/variables rares seraient probablement très utiles.
#
# Enfin, l'élimination des variables doit être dictée par l'objectif que nous avons. Pour l'analyse que feront les agents, l'idéal est ne pas supprimer de variables du tout, ou utiliser une simple règle de seuil NaN, même si en réalité nous pouvons continuer ce projet en toute sécurité. Nous avons un grand ensemble de données, mais il pourrait être beaucoup plus grand.
# Le mieux est la stratégie consistant à construire un nouveau dataframe à partir de la source plutôt que de réduire la forme du dataframe source.
#
# Notez que même 5% de valeurs non nulles dans une variable d'une dataframe de produits vendu en France représentent environ 21 113 observations.

# %%
# Voici une fonction pour faciliter l'exploration :
# Obtenir les variables pour lesquelles le pourcentage
# des valeurs manquantes se situe dans la fourchette basse et haute des %.
def get_variables_with_nan_in_range(data, low, high, dtypes):
    if high >= 100:
        high = 100.1

    nan_counts = data.select_dtypes(dtypes).isnull().sum()
    nan_counts_percent = nan_counts / data.shape[0] * 100

    filter = (nan_counts_percent >= low) & (nan_counts_percent < high)
    nan_counts = nan_counts[filter]
    nan_counts_percent = nan_counts_percent[filter]
    counts = data.shape[0] - nan_counts
    counts_percent = 100 - nan_counts_percent

    return pd.DataFrame({
        'nombre': counts,
        'nombre %': counts_percent,
        'nombre de NaN': nan_counts,
        'nombre de NaN %': nan_counts_percent
    })


# Données alimentaires avec NaN
get_variables_with_nan_in_range(df_fr, 0, 95, 'number')
# Out:
#                                          nombre    nombre %  nombre de NaN  \
# created_t                                769290  100.000000              0
# last_modified_t                          769290  100.000000              0
# serving_quantity                          78040   10.144419         691250
# additives_n                              240747   31.294700         528543
# ingredients_from_palm_oil_n              240747   31.294700         528543
# ingredients_that_may_be_from_palm_oil_n  240747   31.294700         528543
# nutriscore_score                         275751   35.844870         493539
# nova_group                               202232   26.288136         567058
# energy-kj_100g                            70607    9.178203         698683
# energy-kcal_100g                         590202   76.720353         179088
# energy_100g                              617512   80.270379         151778
# fat_100g                                 611477   79.485890         157813
# saturated-fat_100g                       614480   79.876250         154810
# carbohydrates_100g                       611503   79.489269         157787
# sugars_100g                              613638   79.766798         155652
# fiber_100g                               138002   17.938879         631288
# proteins_100g                            613439   79.740930         155851
# salt_100g                                598256   77.767292         171034
# sodium_100g                              598255   77.767162         171035
# nutrition-score-fr_100g                  275755   35.845390         493535
#
#                                          nombre de NaN %
# created_t                                       0.000000
# last_modified_t                                 0.000000
# serving_quantity                               89.855581
# additives_n                                    68.705300
# ingredients_from_palm_oil_n                    68.705300
# ingredients_that_may_be_from_palm_oil_n        68.705300
# nutriscore_score                               64.155130
# nova_group                                     73.711864
# energy-kj_100g                                 90.821797
# energy-kcal_100g                               23.279647
# energy_100g                                    19.729621
# fat_100g                                       20.514110
# saturated-fat_100g                             20.123750
# carbohydrates_100g                             20.510731
# sugars_100g                                    20.233202
# fiber_100g                                     82.061121
# proteins_100g                                  20.259070
# salt_100g                                      22.232708
# sodium_100g                                    22.232838
# nutrition-score-fr_100g                        64.154610

# %% [markdown]
# Dans la fourchette 0-95% de valeurs manquantes, nous avons des variables pour les macronutriments (glucides/lipides/protéines) et le premier niveau des minéraux et vitamines les plus courants. Il nous manque l'amidon, les polyols pour le premier niveau de répartition des glucides; la caséine et les protéines sériques pour les protéines.

# %%
# Distribution des valeurs manquantes par observation
nan_counts_obs = df_fr.isnull().sum(axis=1) / df_fr.shape[1] * 100
nan_counts_obs.hist(bins=20, figsize=(12, 6))

plt.xlim((0, 100))
plt.ylim((0, 130000))
plt.xlabel('Pourcentage des valeurs NaN')
plt.ylabel('# Observations')
plt.title('Distribution des valeurs NaN par observation')
plt.show()

# %% [markdown]
# Concernant les valeurs manquantes par observation, il est intéressant de voir ce pic énorme autour de 85% de valeurs manquantes. Surement causé par kiliweb qui domine ce jeu de données.

# %% [markdown]
# ## Conclusion
#
# En résumé, dans cette première partie, nous avons acquis une meilleure compréhension des données et de leur structure. Nous avons effectué un nettoyage de sécurité et de base. Nous avons décidé de conserver toutes les variables avec les données car les variables présentant un grand nombre de valeurs manquantes ne sont pas synonymes de mauvaises variables et pourront servir pour des analyses.
#
# Dans les sections suivantes, nous construirons des sous-ensembles de données dédiés pour mener nos différentes analyses.
#
# À ce stade, nous disposons d'une base de données source de produits disponibles en France avec laquelle nous pouvons travailler de manière suffisament sereine. Bien sûr, il ne s'agit que d'une première itération de nettoyage et nous devrons nettoyer les données plus en profondeur dans les prochaines sections.

# %% [markdown]
# # Nettoyage en profondeur à l'aide d'analyses statistiques
#
# Dans cette section, nous allons travailler avec les données, approfondir le nettoyage et enquêter sur trois sujets différents qui semblent indispensables pour permettre aux agents de santé publique de mener correctement leurs analyses :
#
# 1. Est-ce que les données sont fiables ? Les réponses pourraient être biaisées et nous n'aurions aucun moyen de le deviner. Qui est exactement kiliweb cette agence web française ? Dans ce premier sujet, nous allons travailler avec `creator`, `created_datetime` et `states_tags` pour avoir une meilleure idée sur la fiabilité des données.
#
# 2. Nous allons enquêter sur les allergènes et essayer de savoir quels allergènes sont les plus communs. Comme les données contiennent plusieurs langues, nous allons d'abord construire un dictionnaire pour traduire les allergènes, car les données sur les allergènes sont désordonnées. Il est important que cette variable soit propre pour permettre aux agents de travailler sur l'étiquetage des allergènes qui est un impératif: https://www.economie.gouv.fr/dgccrf/letiquetage-des-allergenes-imperatif-sante-publique
#
# 3. Enfin, nous travaillerons également avec des données numériques. Nous étudierons la répartition des macronutriments dans les différentes catégories d'aliments `pnns_groups` et nous répondrons à la question de savoir quels sont les aliments qui ont le ratio le plus élevé de fibres. Ce sera également l'occasion d'utiliser certaines méthodes statistiques pour déterminer si nos résultats sont significatifs ou dus au hasard.
#
# Note : Ce projet se limite à un état de l’art de quelques méthodes de nettoyage. Nous aurions pu aller beaucoup plus loin, comme le nettoyage des ingrédients, etc. Néanmoins, le temps de travail s’en trouverait grandement affecté pour du superflu. Avec ces 3 points, il nous est possible de démontrer 3 différentes méthodes de nettoyages sur différent type de variables.

# %% [markdown]
# ## Analyse des sources de données

# %% [markdown]
# ### Sources et collecte des données
#
# D'où viennent les données et comment elles ont été collectées sont les questions auxquelles nous voulons répondre dans cette section. A la fin, le but est d'avoir un esprit critique sur les résultats que nous obtiendrons.
#
# Exemple : Nous avons des données provenant de multiples inventaires de supermarchés contre des produits collectés par des personnes selon leurs propres motivations (avec une application mobile). Dans le premier cas, nous aurions toutes sortes de produits et si les supermarchés ne sont pas des supermarchés alimentaires spécifiques (ex.: aliments bio uniquement), les données ne devraient pas être biaisées. Dans le second cas, où la collecte est le résultat de la motivation des personnes, il est plus probable que les données soient biaisées. Qui s'intéresse aux faits alimentaires, pourquoi et quels produits auraient-ils tendance à acheter et à scanner ? Probablement les personnes qui suivent un régime, les sportifs, etc. Leur choix d'aliments en sera le reflet, tout comme notre ensemble de données. Nous voulons être sûrs que ce n'est pas le cas avec les données que nous fourniront aux agents !
#
# Voyons si pouvons apprendre quelque chose de nouveau de la variable `creator` depuis son nettoyage :

# %%
# Obtenir les 10 premiers contributeurs
df_fr_10_contributors = get_top_10(df_fr, 'creator')

# Afficher le résultat
print('\nLes 10 premiers contributeurs (en nombre et en pourcentage)')
print(df_fr_10_contributors)
show_plot(df_fr_10_contributors, 'creator')

# Afficher des informations sur les observations vides
print_stats(df_fr, 'creator')
# Out:
# Les 10 premiers contributeurs (en nombre et en pourcentage)
#                          creator  Nombre  Pourcentage
# 3122                     kiliweb  602825    78.361216
# 4534  openfoodfacts-contributors   64977     8.446360
# 1419             date-limite-app   21871     2.843011
# 5657                      tacite    8350     1.085416
# 5322                    sebleouf    7342     0.954387
# 4434              nutrinet-sante    4251     0.552587
# 4533          openfood-ch-import    2598     0.337714
# 5710                    teolemon    2357     0.306386
# 5656                     tacinte    2275     0.295727
# 5571                    stephane    2028     0.263620
# Nombre d'enregistrements vides pour creator: 0 (0.0%)
# nunique      6336
# count      769290
# size       769290
# Name: creator, dtype: int64

# %% [markdown]
# Nous constatons que la majorité des données, à quasiment 80% proviennent de kiliweb. En plus de la base de données communautaire `openfoodfacts-contributors`, nous avons également une minorité de données importées de The Food Repo (`openfood-ch-import`), un projet initié par le Digital Epidemiology Lab de l'EPFL. On remarque aussi que les données importé de la base de données nationale sur les nutriments du ministère américain de l'agriculture pour les aliments de marque (`usda-ndb-import`) ont disparu durant le filtrage de produits vendu en France.
#
# Quelques recherches sur le web nous permettent d'identifier les 3 premiers `creator` :
#
# - kiliweb est une startup française qui a développé l'application Yuka qui implémente l'API OpenFoodFacts.
# - openfoodfacts-contributors sont des contributeurs anonymes d'OpenFoodFacts
# - date-limite-app est également une application mobile qui implémente l'API OpenFoodFacts.
# - les autres contributeurs sont des contributeurs enregistrés (Stéphane est probablement le fondateur d'OpenFoodFacts).
#
# Cela signifie également que la distribution de nos données (valeurs manquantes et non manquantes) reflétera majoritairement la structure de la base de données de kiliweb. De plus, nous observerons probablement que la plupart des produits seront originaire de la France et minoritairement de la Suisse car Yuka et OpenFoodFacts sont des projets français et le Food Repo est un projet suisse et que nous avons perdu `usda-ndb-import` durant le processus de filtration.
#
# Concernant la manière dont les données sont collectées :
#
# ![Réponse Yuka](data/images/reponse_yuka_kiliweb.png)
#
# - Yuka reverse via l'agence Kiliweb les contributions de ses utilisateurs. (Merci Marie 😊)
# - Les données du Food Repo sont collectées par des volontaires lorsque les distributeurs donnent accès à leurs magasins. La communauté peut améliorer les données du site web en répondant aux questions sur les données manquantes (toujours le poids/volume).
# - Les données d'OpenFoodFacts sont collectées à partir de l'application mobile qui permet uniquement d'envoyer des photos mais pas de créer/modifier des faits alimentaires. Le site web permet de modifier les faits alimentaires, mais uniquement si l'on est enregistré.
#
# Nous avons probablement beaucoup d'observations avec des valeurs manquantes car il est possible que des personnes qui utilisent l'application, prennent des photos mais ne remplissent jamais la fiche produit sur le site web.
#
# Aussi, il semble qu'OpenFoodFacts n'utilise pas encore l'OCR ou des technologies plus avancées (apprentissage profond, réseau neuronal) pour automatiser le processus à partir de la photo des ingrédients et des faits, mais des projets en ce sens sont en cours. (cf : https://wiki.openfoodfacts.org/OCR/Roadmap)
#
# Au sujet de la fiabilité, les données proviennent des inventaires des magasins, des initiatives des fabricants et des produits scannés par des personnes. L'inconvénient que nous pourrions avoir et que nous avons remarqué précédemment, c'est l'origine des pays biaisé car, à ce stade, il semble probable que la majorités de nos données soient des produits marqué comme français (ex: vu plus haut, la confiture d'origine américaine marqué comme française).
#
# Vérifions cela en commençant par créer une variable `source` à partir de `creator` et vérifions si notre hypothèse sur les pays est correcte.
#
# Dans la suite du projet, nous utiliserons quelques fonctions utilitaires :

# %%
# Obtenir les principales occurrences
def get_top_occurencies(dfallergens, cols, n=10):
    count = dfallergens.groupby(cols).size().sort_values(ascending=False)
    count_percent = round(count / dfallergens.shape[0] * 100, 2)
    return pd.DataFrame({'count': count, 'count %': count_percent}).head(n)


# Obtenir les occurrences les plus importantes contenant
# une expression rationnelle ou une chaîne de caractères.
def get_top_occurencies_containing(dfallergens, col, value, n=10):
    occurences = get_top_occurencies(dfallergens, col, dfallergens.shape[0])
    return occurences[occurences.index.str.contains(
        r'{}'.format(value))].head(n)

# %%
# Contrôler s'il existe d'autres données
# provenant de bases de données externes
get_top_occurencies_containing(df_fr,
                               'creator',
                               value='import|load|dump|database|db|bd|base|\-',
                               n=20)
# Out:
#                             count  count %
# creator
# openfoodfacts-contributors  64977     8.45
# date-limite-app             21871     2.84
# nutrinet-sante               4251     0.55
# openfood-ch-import           2598     0.34
# usda-ndb-import              1110     0.14
# moon-rabbit                   511     0.07
# big-brother                   474     0.06
# systeme-u                     439     0.06
# systeme-u-off                 376     0.05
# org-groupe-ldc                286     0.04
# fleury-michon                 246     0.03
# julie-yuka                    219     0.03
# halal-app-chakib              217     0.03
# org-bernard-royal-dauphine    157     0.02
# org-systeme-u                 146     0.02
# label-biopartenaire           139     0.02
# casino-off                    133     0.02
# org-app-foodbowel             124     0.02
# org-unilever-france-gms       110     0.01
# org-carrefour                 106     0.01

# %% [markdown]
# Visiblement, il n'y a pas d'autres sources de données externes.
#
# Hormis kiliweb qui represente à lui seul quasiment 80% du jeu de données, les applications mobiles qui implémentent l'API d'Open Food Facts peuvent être considérées comme des contributeurs openfoodfacts.
#
# Créons une variable source, avec ce mappage :
#
# - kiliweb => kiliweb
# - openfood-ch-import => foodrepo
# - usda-ndb-import => usda (vérifier s'il existe encore des traces)
# - Tous les autres => openfoodfacts

# %%
# Créer une variable source à partir du mappage suivant
mapping = {
    'kiliweb': 'kiliweb',
    'openfood-ch-import': 'foodrepo',
    'usda-ndb-import': 'usda'
}
df_fr['source'] = df_fr.creator.map(mapping)
df_fr['source'].fillna(value='openfoodfacts', inplace=True)

get_top_occurencies(df_fr, 'source')
# Out:
#                 count  count %
# source
# kiliweb        602825    78.36
# openfoodfacts  162757    21.16
# foodrepo         2598     0.34
# usda             1110     0.14

# %% [markdown]
# Confirmons notre hypothèse sur la distribution des pays par source.

# %%
# Pays les plus courants regroupés par source
get_top_occurencies(df_fr, ['source', 'countries_fr'], n=10)
# Out:
#                                   count  count %
# source        countries_fr
# kiliweb       France             570257    74.13
# openfoodfacts France             127840    16.62
# kiliweb       France,Espagne       8105     1.05
# openfoodfacts France,Allemagne     7959     1.03
# kiliweb       Belgique,France      4518     0.59
# openfoodfacts Belgique,France      4470     0.58
#               France,Suisse        4242     0.55
# kiliweb       France,Allemagne     3710     0.48
#               France,Suisse        2439     0.32
#               France,États-Unis    2301     0.30

# %% [markdown]
# L'hypothèse est confirmée, nous avons bien une majorité d'origine française accompagné d'une minorité Suisse et autres.
#
# Pour résoudre cela il pourra être possible, par exemple, de scrapper une base de données de marques accompagné de leurs origines pour corriger cette variable.
#
# Un autre indicateur de la fiabilité de la donnée serait de visualiser son état grace à la variable `states_fr`. Grâce à elle nous allons nous faire une idée des informations que nous pouvons obtenir des différentes sources de données.

# %% [markdown]
# ### Analyse de l'état de la données
#
# La variable `states_fr` fournit le statut de chaque observation et pourrait être un bon moyen de réduire la taille de notre ensemble de données en fonction de nos besoins pour l'analyse future.
#
# Dans cette section, nous allons :
#
# - Créer des variables indicatrices pour chaque état complété.
# - Analyser si chaque source de données tend à fournir des données pour toutes les variables ou seulement une partie d'entre elles et dans quelle proportion.

# %%
# Exemples de valeurs de states_fr
get_top_occurencies(df_fr, 'states_fr', 5)
# Out:
#                                                      count  count %
# states_fr
# À compléter,Informations nutritionnelles complé...  112933    14.68
# À compléter,Informations nutritionnelles complé...   39252     5.10
# À compléter,Informations nutritionnelles à comp...   35852     4.66
# À compléter,Informations nutritionnelles complé...   27947     3.63
# À compléter,Informations nutritionnelles complé...   25243     3.28

# %% [markdown]
# Nous voulons construire un DataFrame avec chaque état complété comme variable indicatrice, donc nous devons :
#
# 1. Extraire tous les états pour chaque observation (les états sont séparés par une virgule)
# 2. Table pivot pour avoir une variable par état.
# 3. Supprimer les variables qui correspondent aux états non terminés

# %%
# 1. Extraire tous les états (retourne une série multi-indexée
# avec les états extraits comme valeur, <code + match> | state)
# Lors de l'extraction, nous donnons le nom "états" au groupe extrait
# Note : Nous aurions pû aussi utiliser : pd.Series.str.get_dummies(sep=',')
df_states = df_fr.states_fr.str.extractall(r"(?P<états>[^,]+)")
df_states.head(8)
# Out:
#                                                        états
# code          match
# 0000000000017 0                                  À compléter
#               1      Informations nutritionnelles complétées
#               2                      Ingrédients à compléter
#               3                      Date limite à compléter
#               4                   Code emballeur à compléter
#               5                 Caractéristiques à compléter
#               6                       Catégories à compléter
#               7                          Marques à compléter

# %%
# 2. Faire une table pivot afin d'avoir
# une variable pour chaque état individuel.
# (nous devons réinitialiser l'index et créer
# une valeur de colonne pour faire pivoter la table)
df_states.reset_index(inplace=True)
df_states['values'] = 1
df_states = df_states.pivot_table(index='code',
                                  columns='états',
                                  values='values',
                                  fill_value=0)
df_states.head()
# Out:
# états                 Caractéristiques complétées  \
# code
# 0000000000017                                   0
# 0000000000031                                   0
# 0000000000100                                   0
# 00000000001111111111                            0
# 0000000000123                                   0
#
# états                 Caractéristiques à compléter  Catégories complétées  \
# code
# 0000000000017                                    1                      0
# 0000000000031                                    1                      0
# 0000000000100                                    1                      0
# 00000000001111111111                             1                      1
# 0000000000123                                    1                      0
#
# états                 Catégories à compléter  Code emballeur complété  \
# code
# 0000000000017                              1                        0
# 0000000000031                              1                        0
# 0000000000100                              0                        0
# 00000000001111111111                       0                        0
# 0000000000123                              1                        0
#
# états                 Code emballeur à compléter  Complet  \
# code
# 0000000000017                                  1        0
# 0000000000031                                  1        0
# 0000000000100                                  0        0
# 00000000001111111111                           1        0
# 0000000000123                                  1        0
#
# états                 Date limite complétée  Date limite à compléter  \
# code
# 0000000000017                             0                        1
# 0000000000031                             0                        1
# 0000000000100                             1                        0
# 00000000001111111111                      0                        1
# 0000000000123                             0                        1
#
# états                 Emballage complété  ...  Photos à valider  \
# code                                      ...
# 0000000000017                          0  ...                 1
# 0000000000031                          0  ...                 1
# 0000000000100                          0  ...                 1
# 00000000001111111111                   0  ...                 0
# 0000000000123                          0  ...                 1
#
# états                 Quantité complétée  Quantité à compléter  Vérifié  \
# code
# 0000000000017                          0                     1        0
# 0000000000031                          1                     0        0
# 0000000000100                          0                     0        0
# 00000000001111111111                   1                     0        0
# 0000000000123                          0                     1        0
#
# états                 en:front-photo-not-selected  \
# code
# 0000000000017                                   0
# 0000000000031                                   0
# 0000000000100                                   0
# 00000000001111111111                            0
# 0000000000123                                   0
#
# états                 en:ingredients-photo-not-selected  \
# code
# 0000000000017                                         0
# 0000000000031                                         0
# 0000000000100                                         0
# 00000000001111111111                                  0
# 0000000000123                                         0
#
# états                 en:nutrition-photo-not-selected  \
# code
# 0000000000017                                       0
# 0000000000031                                       0
# 0000000000100                                       0
# 00000000001111111111                                0
# 0000000000123                                       0
#
# états                 en:packaging-photo-not-selected  À compléter  À vérifier
# code
# 0000000000017                                       0            1           0
# 0000000000031                                       0            1           0
# 0000000000100                                       0            1           0
# 00000000001111111111                                0            1           0
# 0000000000123                                       0            1           0
#
# [5 rows x 40 columns]

# %%
# 3. Conserver uniquement les états complétés
# (supprimer l'état vide et les états contenant "à", "not" et "non")
columns_to_drop = df_states.columns[df_states.columns.str.contains(
    r'à|À|not|non')]
df_states.drop(axis=1, columns=columns_to_drop, inplace=True)
df_states.head()
# Out:
# états                 Caractéristiques complétées  Catégories complétées  \
# code
# 0000000000017                                   0                      0
# 0000000000031                                   0                      0
# 0000000000100                                   0                      0
# 00000000001111111111                            0                      1
# 0000000000123                                   0                      0
#
# états                 Code emballeur complété  Complet  Date limite complétée  \
# code
# 0000000000017                               0        0                      0
# 0000000000031                               0        0                      0
# 0000000000100                               0        0                      1
# 00000000001111111111                        0        0                      0
# 0000000000123                               0        0                      0
#
# états                 Emballage complété  \
# code
# 0000000000017                          0
# 0000000000031                          0
# 0000000000100                          0
# 00000000001111111111                   0
# 0000000000123                          0
#
# états                 Informations nutritionnelles complétées  \
# code
# 0000000000017                                               1
# 0000000000031                                               0
# 0000000000100                                               1
# 00000000001111111111                                        0
# 0000000000123                                               1
#
# états                 Ingrédients complétés  Marques complétées  \
# code
# 0000000000017                             0                   0
# 0000000000031                             0                   0
# 0000000000100                             1                   0
# 00000000001111111111                      0                   1
# 0000000000123                             0                   0
#
# états                 Nom du produit complété  Origines complétées  \
# code
# 0000000000017                               1                    0
# 0000000000031                               1                    0
# 0000000000100                               0                    0
# 00000000001111111111                        1                    0
# 0000000000123                               1                    0
#
# états                 Photo de face sélectionnée  \
# code
# 0000000000017                                  0
# 0000000000031                                  0
# 0000000000100                                  0
# 00000000001111111111                           0
# 0000000000123                                  0
#
# états                 Photo de l'emballage sélectionnée  \
# code
# 0000000000017                                         0
# 0000000000031                                         0
# 0000000000100                                         0
# 00000000001111111111                                  0
# 0000000000123                                         0
#
# états                 Photo des ingrédients sélectionnée  Photos envoyées  \
# code
# 0000000000017                                          0                1
# 0000000000031                                          0                1
# 0000000000100                                          0                1
# 00000000001111111111                                   0                0
# 0000000000123                                          0                1
#
# états                 Photos validées  Quantité complétée  Vérifié
# code
# 0000000000017                       0                   0        0
# 0000000000031                       0                   1        0
# 0000000000100                       0                   0        0
# 00000000001111111111                0                   1        0
# 0000000000123                       0                   0        0

# %%
# Joindre la variable source
df_states = df_states.join(df_fr.source, how='inner')

# %%
df_states.groupby(df_fr.source).sum()
# Out:
#                Caractéristiques complétées  Catégories complétées  \
# source
# foodrepo                               522                   1694
# kiliweb                              31575                 227740
# openfoodfacts                        68242                 123416
# usda                                   137                   1008
#
#                Code emballeur complété  Complet  Date limite complétée  \
# source
# foodrepo                           197      250                    458
# kiliweb                          44827    14045                  38436
# openfoodfacts                    40049    36347                  51050
# usda                                 7       74                     85
#
#                Emballage complété  Informations nutritionnelles complétées  \
# source
# foodrepo                      968                                     2560
# kiliweb                     64010                                   519599
# openfoodfacts              107806                                   126852
# usda                          199                                     1110
#
#                Ingrédients complétés  Marques complétées  \
# source
# foodrepo                        2351                2446
# kiliweb                       130162              266549
# openfoodfacts                 102603              143099
# usda                            1103                1106
#
#                Nom du produit complété  Origines complétées  \
# source
# foodrepo                          2598                  116
# kiliweb                         602825                 6034
# openfoodfacts                   162756                11726
# usda                              1110                   13
#
#                Photo de face sélectionnée  Photo de l'emballage sélectionnée  \
# source
# foodrepo                             1145                                 16
# kiliweb                            179259                               2850
# openfoodfacts                       60438                               2982
# usda                                  189                                  4
#
#                Photo des ingrédients sélectionnée  Photos envoyées  \
# source
# foodrepo                                     1061             2598
# kiliweb                                     91138           595517
# openfoodfacts                               49560           148415
# usda                                          147             1052
#
#                Photos validées  Quantité complétée  Vérifié
# source
# foodrepo                   633                2384        0
# kiliweb                  73836              118693      647
# openfoodfacts            46641              135483      619
# usda                       137                 258        0

# %%
# Proportion en % des observations avec des états complétés par source
pd.set_option('max_columns', None)
df_states_prop = df_states.groupby(
    df_fr.source).agg(lambda x: round(x.sum() / x.shape[0] * 100, 2))
df_states_prop
# Out:
#                Caractéristiques complétées  Catégories complétées  \
# source
# foodrepo                             20.09                  65.20
# kiliweb                               5.24                  37.78
# openfoodfacts                        41.93                  75.83
# usda                                 12.34                  90.81
#
#                Code emballeur complété  Complet  Date limite complétée  \
# source
# foodrepo                          7.58     9.62                  17.63
# kiliweb                           7.44     2.33                   6.38
# openfoodfacts                    24.61    22.33                  31.37
# usda                              0.63     6.67                   7.66
#
#                Emballage complété  Informations nutritionnelles complétées  \
# source
# foodrepo                    37.26                                    98.54
# kiliweb                     10.62                                    86.19
# openfoodfacts               66.24                                    77.94
# usda                        17.93                                   100.00
#
#                Ingrédients complétés  Marques complétées  \
# source
# foodrepo                       90.49               94.15
# kiliweb                        21.59               44.22
# openfoodfacts                  63.04               87.92
# usda                           99.37               99.64
#
#                Nom du produit complété  Origines complétées  \
# source
# foodrepo                           100                 4.46
# kiliweb                            100                 1.00
# openfoodfacts                      100                 7.20
# usda                               100                 1.17
#
#                Photo de face sélectionnée  Photo de l'emballage sélectionnée  \
# source
# foodrepo                            44.07                               0.62
# kiliweb                             29.74                               0.47
# openfoodfacts                       37.13                               1.83
# usda                                17.03                               0.36
#
#                Photo des ingrédients sélectionnée  Photos envoyées  \
# source
# foodrepo                                    40.84           100.00
# kiliweb                                     15.12            98.79
# openfoodfacts                               30.45            91.19
# usda                                        13.24            94.77
#
#                Photos validées  Quantité complétée  Vérifié
# source
# foodrepo                 24.36               91.76     0.00
# kiliweb                  12.25               19.69     0.11
# openfoodfacts            28.66               83.24     0.38
# usda                     12.34               23.24     0.00

# %% [markdown]
# kiliweb semble être le jeu de donnée le moins complet. Et openfoodfacts semble être le plus complet. Observons cela sur un graphique.

# %%
# Dessiner un graphique pour les faits, les ingrédients,
# les catégories et les états complétés par source.
df_states_prop.loc[:, [
    'Informations nutritionnelles complétées', 'Ingrédients complétés',
    'Catégories complétées', 'Complet'
]].plot.bar(figsize=(12, 6))

plt.xlabel('Source de données')
plt.ylabel('Complété en %')
plt.title(
    "Pourcentage complété pour les différents états par sources de données")
plt.show()

# %% [markdown]
# Comme nous pouvons le constater, de manière générale les sources ne fournissent que le nom du produit, la marque, les ingrédients et les données nutritionnelles. Cela reflète bien le processus de collecte dans lequel les fabricants fournissent les données.
#
# Graphiquement, la source openfoodfacts semble bien être la source la plus complète des 4 (en rouge).
#
# Dans une prochaine section, nous classerons les produits alimentaires par `pnns_group`.
#
# Terminons cette section en comparant le nombre de valeurs manquantes entre kiliweb et les contributeurs (openfoodfacts). Cette comparaison peut servir d'indice sur la qualité du jeu de données de kiliweb qui est dominant comparé à celle des autres contributeurs. Par exemple, est-ce que Yuka applique un traitement particulier sur les données avant de les transmettre à kiliweb ? Nous affichons la distribution des valeurs manquantes par observations empilées par `source`.

# %%
# Distribution de valeurs NaN sur les lignes empilées par source.
dict = {}
for source in get_top_occurencies(df_fr, 'source').index:
    df_source = df_fr[df_fr.source == source]
    dist = df_source.isnull().sum(axis=1) / df_source.shape[1] * 100
    dict[source] = dist

fig, ax = plt.subplots(nrows=2, ncols=1)
pd.DataFrame(dict).plot.hist(ax=ax[0], stacked=True, bins=20, figsize=(10, 11))
pd.DataFrame(dict).plot.hist(ax=ax[1],
                             logy=True,
                             stacked=True,
                             bins=20,
                             figsize=(10, 11))
plt.subplots_adjust(hspace=0.3)
ax[0].set_xlim(0, 100)
ax[1].set_xlim(0, 100)
ax[0].set_ymargin(1)
ax[0].set_xlabel('Pourcentage de valeurs NaN')
ax[1].set_xlabel('Pourcentage de valeurs NaN')
ax[0].set_ylabel('# Observation')
ax[1].set_ylabel('$Log(\# Observation)$')
ax[0].set_title(
    'Distribution de valeurs NaN par observation, empilée par source')
ax[1].set_title(
    'Distribution logarithmique de valeurs NaN par observation, empilées par source.'
)
ax[0].legend(loc='upper left')
ax[1].legend(loc='upper left')
plt.show()

# %% [markdown]
# Nous voyons clairement que le pic est causé par la source de données kiliweb et les contributeurs d'open et cela confirme notre intuition. Le graphique logarithmique donne une meilleure idée de l'état d'avancement des données du projet openfoodfacts.
#
# Dans ce point de vue, proportionnellement, la source openfoodfacts semble contenir plus de NaN que kiliweb.
#
# Les parties précédentes étaient trop techniques et proches de la base de données mais nous connaissons nos données et leur raison d'être maintenant. Plongeons dans la dimension temporelle et enquêtons sur le groupe de travail à l'origine du projet openfoodfacts pour savoir s'il s'agit d'un projet sain ou d'un projet opensource en voie de disparition.

# %% [markdown]
# ### Nombre de produits ajoutés chaque mois et évolution au fil du temps

# %% [markdown]
# Nous allons utiliser la variable `created_datetime` pour procéder aux analyses suivantes :
#
# - Quand l'intégration de kiliweb a débuté ?
# - Observer le nombre de produits ajoutés dans la base de données openfoodfacts chaque mois.
# - La croissance du nombre de produits dans la base de données openfoodfacts sur la durée de notre jeu de données.

# %%
# Vérifier quand l'intégration de la base de données kiliweb a été faite.
df_fr.loc[df_fr.source == 'kiliweb'].groupby(
    df_fr.created_datetime.dt.date).size()
# Out:
# created_datetime
# 2016-03-22      1
# 2016-05-23      1
# 2016-05-30      2
# 2016-06-01      4
# 2016-06-02      2
#              ...
# 2021-04-14    350
# 2021-04-15    263
# 2021-04-16    346
# 2021-04-17    395
# 2021-04-18      2
# Length: 1644, dtype: int64

# %% [markdown]
# Nous pouvons voir que kiliweb a été inclus dans l'ensemble de données en mars 2016, soit 5 ans après la création d'Open Food Fact, et fourni quotidiennement de plus en plus de données jusqu'à présent.
#
# Visualisons le nombre de produits ajoutés chaque mois dans la base de données openfoodfacts. Nous devons d'abord construire une série temporelle avec le nombre de produits créés chaque jour :

# %%
# Nombre de produits créés chaque jour
counts_per_day = df_fr[df_fr.source == 'openfoodfacts'].groupby(
    df_fr.created_datetime.dt.date).size()

# Définir l'index comme un index de date
counts_per_day.index = pd.to_datetime(counts_per_day.index)

# Remplir le trou dans les données (jours manquants) avec 0 produits créés.
counts_per_day = counts_per_day.asfreq('D', fill_value=0)

# %%
# Rééchantillonner la série temporelle pour obtenir le nombre d'éléments créés par mois.
counts_per_month = counts_per_day.resample('M').sum()
counts_per_month.head()
# Out:
# created_datetime
# 2012-01-31      1
# 2012-02-29     12
# 2012-03-31    142
# 2012-04-30    139
# 2012-05-31    371
# Freq: M, dtype: int64

# %%
# Tracez le nombre de produits créés chaque mois.
counts_per_month.plot(figsize=(12, 7))
plt.xlabel('Année')
plt.ylabel('Nombre de produits')
plt.title(
    'Nombre de produits créés chaque mois dans la base de données OpenFoodFacts'
)
plt.show()

# %% [markdown]
# Même sans compter kiliweb, le projet Openfood fact est en bonne santé. Une somme cumulative du nombre de produits sur la ligne de temps nous donnera une meilleure visualisation.

# %%
# Tracer la somme cumulée du nombre de produits dans le temps et aussi sa racine carrée.
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(12, 12))
counts_per_day.cumsum().plot(ax=ax1)
np.sqrt(counts_per_day.cumsum()).plot(ax=ax2)
ax1.set_xlabel('Année')
ax2.set_xlabel('Année')
ax1.set_ylabel('Nombre de produits')
ax2.set_ylabel('$\sqrt{Nombre\:de\:produits}$')
ax1.set_title(
    'Évolution dans le temps du nombre de produits dans la base de données OpenFoodFacts'
)
ax2.set_title(
    'Évolution dans le temps de la racine carrée du nombre de produits dans la base de données OpenFoodFacts'
)
plt.show()

# %% [markdown]
# On constate que la racine carrée du nombre de produits dans la base de données croît linéairement dans le temps.
# Le nombre de produits dans la base de données suit une tendance quadratique.

# %% [markdown]
# ### Conclusion
#
# Ceci clôt notre première analyse thématique. Elle était définitivement plus technique que scientifique, mais nous avons appris beaucoup de choses sur nos données.
#
# Le projet openfoodfacts est un projet sain qui intéresse les gens et j'espère qu'ils amélioreront la manière dont les données sont collectées, avec des technologies qui pourraient améliorer la qualité des données de manière automatisée.

# %% [markdown]
# ## Analyse des allergènes
#
# Dans cette analyse, nous allons nous concentrer sur les allergènes et essayer de trouver les allergènes les plus courants.
#
# Commençons par extraire un DataFrame avec les variables requises

# %%
# Construirir un DataFrame avec les variables requises
dfallergens = df_fr.loc[df_fr.allergens.notnull(),
                        ['product_name', 'allergens', 'source']].copy()

print('Forme du DataFrame: {}'.format(dfallergens.shape))
dfallergens.head()
# Out:
# Forme du DataFrame: (86464, 3)
#                                      product_name                  allergens  \
# code
# 0000000000100         moutarde au moût de raisin                  en:mustard
# 0000000001199              Solène céréales poulet         en:eggs,en:mustard
# 0000000002264                   Baguette Poitevin          en:gluten,en:milk
# 0000000003827                      Suedois saumon  en:fish,en:gluten,en:milk
# 0000000004794  Fromage blanc à la creme de marron                    en:milk
#
#                       source
# code
# 0000000000100  openfoodfacts
# 0000000001199        kiliweb
# 0000000002264        kiliweb
# 0000000003827        kiliweb
# 0000000004794        kiliweb

# %%
# Afficher les données sur les allergènes pour avoir une idée du nettoyage à effectuer.
dfallergens.allergens.head(10)
# Out:
# code
# 0000000000100                   en:mustard
# 0000000001199           en:eggs,en:mustard
# 0000000002264            en:gluten,en:milk
# 0000000003827    en:fish,en:gluten,en:milk
# 0000000004794                      en:milk
# 0000000005272    en:gluten,en:sesame-seeds
# 0000000005470            en:eggs,en:gluten
# 0000003075647                  en:soybeans
# 0000005016                 en:milk,en:nuts
# 0000005018                         en:none
# Name: allergens, dtype: object

# %% [markdown]
# Impossible de le remarquer dans cet aperçu, cependant les données ne sont pas propres.
#
# Exemple :
# - Parenthèses incomplètes
# - Mauvaise écriture des allergènes
# - Doublons
# - "en:Lait"
# - "fr:—-o.alités gustatives. \"
# - gt40ai,gt40ba,gt40bo,gt40bp,gt40bs,gt40cn...
# - "a eviter (d'après c gouget),e2 troubles digestifs/nausées/contrarie la vitamine b/mutagéne/,e3 interdit en australie/dangereux pour les jeunes enfants/troubles de la coagulation du sang/vomissement/diarrhées/crampes abdominales ou musculaires etc,elimine le calcium,maux de tête,test sur anima endommagement des chromosomes etc"
#
# Les données sont désordonnées, beaucoup de doublons, de synonymes pour le même type d'allergènes, de langues multiples (français, anglais, mais beaucoup d'autres comme de l'Espagnole), certaines sont en majuscules, etc.

# %% [markdown]
# Nous allons aborder la préparation des données en cinq étapes :
#
# 1. Nettoyage des données par manipulation de texte : tout en minuscules, suppression des espaces et autres.
# 2. Extraction des allergènes individuels pour obtenir un DataFrame avec un allergène par observation (donc plusieurs observations par produits).
# 3. Construction d'un dictionnaire avec la traduction et les synonymes des allergènes à partir de ce jeu de données : https://github.com/openfoodfacts/openfoodfacts-server/blob/main/taxonomies/allergens.txt
# 4. Traduire nos données et supprimer les doublons après traduction.
# 5. Trouver les allergènes les plus courants.

# %% [markdown]
# ### Nettoyage des données

# %%
# Tout en minuscules
dfallergens['allergens_c'] = dfallergens.allergens.str.lower()

# Suppression des espaces blancs
dfallergens.allergens_c = dfallergens.allergens_c.str.strip()

# Remplacer les espaces multiples par un seul espace.
dfallergens.allergens_c = dfallergens.allergens_c.str.replace(r"\s+", " ")

# Supprimer les espaces après les virgules
dfallergens.allergens_c = dfallergens.allergens_c.str.replace(r",\s+", ",")

# Suppression de certains caractères spéciaux
dfallergens.allergens_c = dfallergens.allergens_c.str.replace(
    r"[\*|\?|\.]", "")
# Suppression de l'indication des langues
dfallergens.allergens_c = dfallergens.allergens_c.str.replace(r"..:", "")

# TODO : Réaliser un regex pour supprimer les erreurs de backspaces et de parenthèses
# Cette méthode est provisoire
dfallergens = dfallergens.drop([
    '3222476083982', '3564707139809', '3368955876369', '3256227361081',
    '3256220365796', '3256220365796', '3256225722563'
])

# %%
# Vérifier le résultat après le nettoyage
dfallergens.allergens_c.tail()
# Out:
# code
# 9780141185187                                 crustaceans,gluten
# 98227389                                                    milk
# 9876754344551    eggs,gluten,milk,nuts,peanuts,biscuit spéculoos
# 98797554                                             gluten,milk
# 9900000001926                          gluten,milk,nuts,soybeans
# Name: allergens_c, dtype: object

# %% [markdown]
# ### Extraction des allergènes
#
# Nous voulons un DataFrame avec un allergène par observation.

# %%
# Extraire les allergènes (une observation par code et par allergène, multi-index = code + match )
df_allergens = dfallergens.allergens_c.str.extractall(r"(?P<allergen>[^,]+)")

# Réinitialiser l'index
df_allergens.reset_index(inplace=True)

# Supprimer la colonne créée automatiquement : match
df_allergens.drop('match', axis=1, inplace=True)

# Supprimer les doublons
df_allergens.drop_duplicates(inplace=True)

df_allergens.head()
# Out:
#             code allergen
# 0  0000000000100  mustard
# 1  0000000001199     eggs
# 2  0000000001199  mustard
# 3  0000000002264   gluten
# 4  0000000002264     milk

# %% [markdown]
# Il nous manque le nom du produit et la source, fusionnons les deux dataframes.

# %%
# Définir 'code' comme index
df_allergens.set_index('code', inplace=True)

# Fusionner les DataFrame pour avoir un allergène
# par observation avec la description du produit.
df_allergens = df_allergens.merge(dfallergens.loc[:,
                                                  ['product_name', 'source']],
                                  on='code')
df_allergens.head()
# Out:
#               allergen                  product_name         source
# code
# 0000000000100  mustard   moutarde au moût de raisin   openfoodfacts
# 0000000001199     eggs        Solène céréales poulet        kiliweb
# 0000000001199  mustard        Solène céréales poulet        kiliweb
# 0000000002264   gluten             Baguette Poitevin        kiliweb
# 0000000002264     milk             Baguette Poitevin        kiliweb

# %% [markdown]
# ### Construire un dictionnaire des taxonomies des allergènes
#
# Nos données sont maintenant prêtes à être traduites, nous devons maintenant construire un dictionnaire pour traduire les allergènes et remplacer les différents synonymes par leurs taxonomies correspondantes. Le GitHub d'OpenFoodFact fournit les taxonomies à cette url : https://github.com/openfoodfacts/openfoodfacts-server/tree/main/taxonomies
#
# Sur cette page, on peut voir les différentes taxonomies : fr:gluten, fr:crustacés, fr:œufs, etc. avec différents synonymes dans de nombreuses langues différentes.
#
# Note : Il nous est aussi possible de reconstruire les allergènes grâce aux ingrédients à l'aide du fichier "allergens.result.txt"

# %%
# Récupération du fichier contenant les taxonomies d'allergènes
taxonomies = requests.get(
    'https://raw.githubusercontent.com/openfoodfacts/openfoodfacts-server/main/taxonomies/allergens.txt'
)
taxonomies = str(taxonomies.text)

# %% [markdown]
# Les différentes taxonomies d'allergènes sont séparées par des lignes vides.
# Nous pouvons construire une liste en séparant le texte avec ce séparateur, et construire un dataframe à partir de la liste.

# %%
# Supprimer le flag "stopwords" au début du fichier
taxonomies = re.sub(r'stopwords.*?\n', '', taxonomies)

# Supprimer l'annotation wikidata à la fin de chaque taxonomie
taxonomies = re.sub(r'wikidata.*', '', taxonomies)

# Supprimer les lignes vides
taxonomies = re.sub(r'^(?:[\t ]*(?:\r?\n|\r))+', '\n', taxonomies)

# Supprimer les commentaires
taxonomies = re.sub(r'\n#.*', '', taxonomies)

# Supprimez les espaces après la virgule.
taxonomies = re.sub(r',\s+', ',', taxonomies)

# Retirer les 3 retours à la ligne successif
taxonomies = re.sub("([ \t]*\n){3,}", "\n\n", taxonomies)

# Retirer les espaces
taxonomies = taxonomies.strip()

# Tout en minuscules
taxonomies = taxonomies.lower()

# Les allergènes avec leurs synonymes et leurs traductions sont séparés par une ligne vide.
taxonomies = taxonomies.split('\n\n')

# %%
# Construire un dataframe
taxonomies = pd.DataFrame({'text': taxonomies})
taxonomies.head()
# Out:
#                                                 text
# 0  en:none,allergens-free,without allergens,witho...
# 1  en:gluten,cereals containing gluten,barley,bar...
# 2  en:crustaceans,crab,lobster,crayfish,prawn,shr...
# 3  en:eggs,egg,barn egg,egg whites,egg white,egg ...
# 4  en:fish,fishes,cod,mackerel,flounder,halibut,t...

# %% [markdown]
# La taxonomie est le premier mot après le drapeau "fr" sur chaque observation. Extrayons-les et remplaçons l'index par ceux-ci

# %%
# Extraire la taxonomie principale des allergènes
# du premier mot français jusqu'à la virgule ou le retour à la ligne
taxonomies['allergen'] = taxonomies.text.str.extract(r'fr:([^\n,]+)')

# Définir l'allergène comme index du dataframe.
taxonomies.set_index('allergen', inplace=True)

taxonomies.head()
# Out:
#                                                         text
# allergen
# aucun      en:none,allergens-free,without allergens,witho...
# gluten     en:gluten,cereals containing gluten,barley,bar...
# crustacés  en:crustaceans,crab,lobster,crayfish,prawn,shr...
# œufs       en:eggs,egg,barn egg,egg whites,egg white,egg ...
# poisson    en:fish,fishes,cod,mackerel,flounder,halibut,t...

# %%
taxonomies.head(100)
# Out:
#                                                                               text
# allergen
# aucun                            en:none,allergens-free,without allergens,witho...
# gluten                           en:gluten,cereals containing gluten,barley,bar...
# crustacés                        en:crustaceans,crab,lobster,crayfish,prawn,shr...
# œufs                             en:eggs,egg,barn egg,egg whites,egg white,egg ...
# poisson                          en:fish,fishes,cod,mackerel,flounder,halibut,t...
# arachides                        en:peanuts,peanut,arachis hypogaea\nar:فول سود...
# soja                             en:soybeans,soya,soja,soia,soy,soya bean,soy f...
# lait                             en:milk,lactose,whey,dairy,butter,buttermilk,c...
# fruits à coque                   en:nuts,almonds,hazelnuts,walnuts,cashews,cash...
# céleri                           en:celery,celeriac\nar:كرفس\nbg:целина\ncs:cel...
# moutarde                         en:mustard,brassica\nar:خردل\nbg:синап\ncs:hoř...
# graines de sésame                en:sesame seeds,sesame\nar:سمسم\nbg:сусамово с...
# anhydride sulfureux et sulfites  en:sulphur dioxide and sulphites,sulphur dioxi...
# lupin                            en:lupin,lupine\nar:ترمس\nbg:лупина\ncs:vlčí b...
# mollusques                       en:molluscs,mollusc,mollusks,mollusk,squid,cut...

# %% [markdown]
# Nous devons maintenant extraire chaque langue pour avoir une ligne par allergène et par langue. Les langues sont séparées par un retour à la ligne

# %%
# Extract all langages (to have one row per allergen and langages)
allergens_translations = taxonomies.text.str.extractall(
    r'(?P<translations>[^\n]+)')

# Reset index
allergens_translations.reset_index(inplace=True)

# Drop the automatically created match column
allergens_translations.drop(['match'], axis=1, inplace=True)

allergens_translations.head()
# Out:
#   allergen                                       translations
# 0    aucun  en:none,allergens-free,without allergens,witho...
# 1    aucun  fr:aucun,aucune,sans allergènes,sans,pas,pas d...
# 2    aucun  sr:ništa,nijedan,nijedno,bez alergena,nema ale...
# 3   gluten  en:gluten,cereals containing gluten,barley,bar...
# 4   gluten                                          ar:غلوتين

# %% [markdown]
# ### Traduction des allergènes
# Nous avons maintenant tout pour remplacer les données sources des allergènes par leurs taxonomies correspondantes :

# %%
# Fonction qui renvoie la taxonomie de l'allergène
# si elle est trouvée ou sinon l'allergène déjà existant
def get_allergen_translation(x):
    result = allergens_translations[
        allergens_translations.translations.str.contains(x)]
    if result.shape[0] > 0:
        return result.allergen.iloc[0]
    else:
        return x


# Fonction qui renvoie si une taxonomie d'allergène a été trouvée
def has_translation(x):
    result = allergens_translations[
        allergens_translations.translations.str.contains(x)]
    return result.shape[0] > 0


# Ajouter une variable avec la traduction/taxonomie des allergènes
df_allergens['allergen_translation'] = df_allergens.allergen.map(
    get_allergen_translation)

# Ajouter une variable qui indique si une traduction/taxonomie a été trouvée
df_allergens['translated'] = df_allergens.allergen.map(has_translation)

# %% [markdown]
# Comme nous pouvons avoir plusieurs synonymes pour la même taxonomie d'allergènes, nous avons probablement de nouveaux doublons après la traduction. Nous devons les supprimer :

# %%
# Réinitialiser l'index
df_allergens.reset_index(inplace=True)

# Supprimer les doublons créés par la traduction parce
# qu'un produit a plusieurs synonymes pour le même allergène
df_allergens.drop_duplicates(subset=['code', 'allergen_translation'],
                             inplace=True)

# Capitaliser la traduction de l'allergène
df_allergens.allergen_translation = df_allergens.allergen_translation.str.capitalize(
)

df_allergens.loc[:,
                 ['code', 'product_name', 'allergen', 'allergen_translation'
                  ]].head(10)
# Out:
#             code                        product_name allergen  \
# 0  0000000000100         moutarde au moût de raisin   mustard
# 1  0000000001199              Solène céréales poulet     eggs
# 2  0000000001199              Solène céréales poulet  mustard
# 3  0000000002264                   Baguette Poitevin   gluten
# 4  0000000002264                   Baguette Poitevin     milk
# 5  0000000003827                      Suedois saumon     fish
# 6  0000000003827                      Suedois saumon   gluten
# 7  0000000003827                      Suedois saumon     milk
# 8  0000000004794  Fromage blanc à la creme de marron     milk
# 9  0000000005272   Sandwich solene céréales sicilien   gluten
#
#   allergen_translation
# 0             Moutarde
# 1                 Œufs
# 2             Moutarde
# 3               Gluten
# 4                 Lait
# 5            Crustacés
# 6               Gluten
# 7                 Lait
# 8                 Lait
# 9               Gluten

# %% [markdown]
# Nous avons maintenant des données intéressantes prêtes à être analysées.

# %%
# Calculer le ratio de traduction.
translation_percent = np.round(
    df_allergens.translated.sum() / df_allergens.shape[0] * 100, 2)

print("Pourcentage de traduction des taxonomies d'allergènes : {}%".format(
    translation_percent))
# Out:
# Pourcentage de traduction des taxonomies d'allergènes : 92.92%

# %% [markdown]
# Nous pourrions améliorer ce pourcentage en traitant la forme plurielle de certains mots. Par exemple, "fromages" n'a pas été traduit par "Lait" car il est au pluriel.

# %% [markdown]
# ### Analyse : Les allergènes les plus courants

# %%
allergens_occurences = get_top_occurencies(
    df_allergens[df_allergens.translated], 'allergen_translation', 20)
allergens_occurences
# Out:
#                                  count  count %
# allergen_translation
# Lait                             47759    30.91
# Gluten                           41028    26.55
# Œufs                             19155    12.40
# Soja                             16175    10.47
# Arachides                        11736     7.59
# Crustacés                         7221     4.67
# Moutarde                          5193     3.36
# Céleri                            4147     2.68
# Mollusques                        1326     0.86
# Aucun                              346     0.22
# Lupin                              333     0.22
# Fruits à coque                      63     0.04
# Poisson                             27     0.02
# Anhydride sulfureux et sulfites     21     0.01
# Graines de sésame                    3     0.00

# %%
# Tracer un diagramme en bâtons des allergènes les plus courants
ax = allergens_occurences['count'].plot.barh(figsize=(12, 8), color='#4352a2')
ax.invert_yaxis()
ax.xaxis.grid()

plt.title('Nombre de produits référencés contenant divers allergènes')
plt.xlabel('Nombre de produits référencés')
plt.ylabel('Allergènes')
plt.show()

# %% [markdown]
# Les personnes intolérante au lactose et au gluten se voient privé d'une grande majorité de produits.

# %% [markdown]
# ### Conclusion
#
# Nous terminons notre deuxième thème d'analyse. Nous constatons que le lait et le gluten sont de loin les allergènes les plus courants. Les oeufs et le soja sont également courants. En creusant dans les données, nous pouvons constater que les sandwichs, les plats uniques et les aliments préparés en général contiennent le plus d'allergènes. Les boîtes de sushis peuvent contenir plus de 8 allergènes différents par exemple.
#
# Pour une exploration plus approfondie, le Dataframe suivant permet de filtrer facilement les produits par allergènes (transformés en variables indicatrices) et fournit également le nombre d'allergènes par produit.

# %%
# Table pivot pour avoir une variable pour chaque taxonomie d'allergène.
# avec True/False indiquant si le produit contient l'allergène correspondant
df_allergens_pivot = df_allergens[df_allergens.translated].pivot_table(
    index='code',
    columns='allergen_translation',
    values='translated',
    fill_value=False)

# Compter le nombre d'allergènes par produit
df_allergens_pivot['allergen_count'] = df_allergens_pivot.sum(axis=1)

# Récupérer la variable product_name en rejoignant le dataframe df_alergens
df_allergens_pivot = pd.concat([df_allergens_pivot, df_fr.product_name],
                               axis=1,
                               join='inner')

# Réindexer les colonnes
cols = ['product_name', 'allergen_count'
        ] + df_allergens_pivot.columns[0:13].values.tolist()
df_allergens_pivot = df_allergens_pivot.reindex(columns=cols)

# Exemple : Produits avec au moins 8 allergènes et qui contiennent du gluten
df_allergens_pivot[(df_allergens_pivot.allergen_count >= 8)
                   & df_allergens_pivot['Gluten']]
# Out:
#                                                     product_name  \
# 3292590838584   True  False       True     True   False
# 3292590879839   True  False       True     True   False
# 3292590882525   True   True       True     True   False
# 3350033434745   True  False       True     True   False
# 3350033434776   True  False       True     True   False
# 3368951152238   True   True       True     True   False
# 3436590020079   True  False       True     True   False
# 3450611130011   True   True       True     True   False
# 3456300009408   True  False       True     True   False
# 3535000050160   True   True       True     True   False
# 3565270006246   True  False       True     True   False
# 3663219003346   True   True       True     True   False
# 3663219003612   True   True       True     True   False
# 3663219003889   True   True       True     True   False
# 3700091900230   True  False       True     True   False
# 3760018710014   True   True      False     True   False
# 3760094448221   True  False       True     True   False
# 5411153008778   True   True       True    False   False
# 5411153010153   True   True       True     True   False

# %% [markdown]
# De cette manière les agents peuvent facilement mener une étude sur les allergènes.

# %% [markdown]
# ## Composition des macronutriments des aliments et énergie

# %% [markdown]
# Dans cette analyse, nous allons étudier la répartition des macronutriments dans les différents types d'aliments. Nous utiliserons les variables de classification `pnns_groups` pour résumer nos résultats. Nous allons voir s'il existe une corrélation entre l'énergie et la répartition des macronutriments (glucides, lipides et protéines).
#
# Commençons par construire un dataframe avec les produits avec les groupes pnns et faisons un peu de nettoyage.

# %%
# Construire un dataframe avec seulement le produit
# ayant des groupes de pnns et une énergie supérieure à 0.
df_nutrients = df_fr.loc[(df_fr.pnns_groups_1.notnull()) &
                         (df_fr.pnns_groups_2.notnull()) &
                         (df_fr.energy_100g > 0), :].copy()

print('Forme du dataframe: {}'.format(df_nutrients.shape))
# Out:
# Forme du dataframe: (599778, 178)

# %% [markdown]
# ### Nettoyage de la variable PNNS (Programme National Nutrition Santé)

# %%
# Obtenir les valeurs existantes du Groupes 1 PNNS
pd.DataFrame({'PNNS Group 1': df_nutrients.pnns_groups_1.unique()})
# Out:
#                PNNS Group 1
# 0                   unknown
# 1            Fat and sauces
# 2           Composite foods
# 3             Sugary snacks
# 4     Fruits and vegetables
# 5   Milk and dairy products
# 6            Fish Meat Eggs
# 7      Cereals and potatoes
# 8              Salty snacks
# 9                 Beverages
# 10            sugary-snacks
# 11    fruits-and-vegetables
# 12     cereals-and-potatoes
# 13             salty-snacks

# %%
# Obtenir les valeurs existantes du groupe 2 du PNNS
pd.DataFrame({'PNNS Group 2': df_nutrients.pnns_groups_2.unique()})
# Out:
#                         PNNS Group 2
# 0                            unknown
# 1               Dressings and sauces
# 2                     One-dish meals
# 3                 Biscuits and cakes
# 4                             Fruits
# 5                             Cheese
# 6                               Meat
# 7                              Bread
# 8                   Fish and seafood
# 9           Salty and fatty products
# 10                      Fruit juices
# 11                            Sweets
# 12                              Fats
# 13                    Dairy desserts
# 14             Pizza pies and quiche
# 15               Sweetened beverages
# 16             Unsweetened beverages
# 17                              Nuts
# 18                           Cereals
# 19                        Appetizers
# 20                      Dried fruits
# 21                          pastries
# 22                        Vegetables
# 23                 Breakfast cereals
# 24                    Processed meat
# 25                        Sandwiches
# 26                           Legumes
# 27                   Milk and yogurt
# 28  Teas and herbal teas and coffees
# 29                             Soups
# 30                          Potatoes
# 31  Artificially sweetened beverages
# 32                Chocolate products
# 33      Plant-based milk substitutes
# 34                            Offals
# 35                        vegetables
# 36                         Ice cream
# 37                     Fruit nectars
# 38                              Eggs
# 39        Waters and flavored waters
# 40                            fruits
# 41                           legumes
# 42                           cereals
# 43                              nuts

# %% [markdown]
# Comme on peut le voir, pour les deux groupes, nous avons quelques doublons qui peuvent être éliminés en remplaçant les - par des espaces et en mettant tout en capitalisé.

# %%
# Strip
df_nutrients.pnns_groups_1 = df_nutrients.pnns_groups_1.str.strip()
df_nutrients.pnns_groups_2 = df_nutrients.pnns_groups_2.str.strip()

# Mettre la première lettre en majuscule à tous les groupes
df_nutrients.pnns_groups_1 = df_nutrients.pnns_groups_1.str.capitalize()
df_nutrients.pnns_groups_2 = df_nutrients.pnns_groups_2.str.capitalize()

# Remplacer les - par des espaces
df_nutrients.pnns_groups_1 = df_nutrients.pnns_groups_1.str.replace('-', ' ')
df_nutrients.pnns_groups_2 = df_nutrients.pnns_groups_2.str.replace('-', ' ')

# %%
# Vérifier le nettoyage
pd.DataFrame({'Groupe PNNS 1': df_nutrients.pnns_groups_1.unique()})
# Out:
#              Groupe PNNS 1
# 0                  Unknown
# 1           Fat and sauces
# 2          Composite foods
# 3            Sugary snacks
# 4    Fruits and vegetables
# 5  Milk and dairy products
# 6           Fish meat eggs
# 7     Cereals and potatoes
# 8             Salty snacks
# 9                Beverages

# %% [markdown]
# ### Sélection des variables et des observations

# %% [markdown]
# Ici, nous ne gardons que les observations et les variables que nous utiliserons pendant l'analyse. Dans les données, il y a des produits classés avec des groupes PNNS inconnus (`Unknown`), nous les supprimerons car ils ne sont pas informatifs. Concernant les faits, notre analyse ne portera que sur les faits de premier niveau présents sur chaque produit (glucides, lipides, protéines, fibres et sel).
#
# Mais dans un but de nettoyage uniquement, nous prendrons également leur première décomposition en sous-niveaux et vérifierons si les données sont cohérentes entre le niveau supérieur et leur décomposition (exemple : les glucides doivent être supérieurs à la somme du sucre, de l'amidon et des polyols). Pour nettoyer ces incohérences potentielles, nous devons remplacer les valeurs manquantes par 0.

# %%
# Variables que nous voulons conserver
# macronutriments de niveau supérieur (ex : protéines, lipides, glucides)
# et leur premier niveau de sous catégorie
# (ex : Lipides = graisse saturée, monoinsaturés, ...)
col_list = [
    'product_name', 'pnns_groups_1', 'pnns_groups_2', 'source', 'energy_100g',
    'carbohydrates_100g', 'sugars_100g', 'starch_100g', 'polyols_100g',
    'fat_100g', 'saturated-fat_100g', 'monounsaturated-fat_100g',
    'polyunsaturated-fat_100g', 'trans-fat_100g', 'proteins_100g',
    'casein_100g', 'serum-proteins_100g', 'fiber_100g', 'salt_100g'
]

# Variables qui seront utilisées pour l'analyse
# uniquement les macronutriments de niveau supérieur et l'énergie
facts_for_analysis = [
    'energy_100g', 'carbohydrates_100g', 'fat_100g', 'proteins_100g',
    'fiber_100g', 'salt_100g'
]

# Conserver uniquement les variables requises et
# exclure les groupes de PNNS inconnus (Unknown)
df_nutrients = df_nutrients[df_nutrients.pnns_groups_1 != 'Unknown'].reindex(
    columns=col_list)

# Supprimer les observations avec des valeurs
# manquantes en macronutriments et en énergie
# df_nutrients.dropna(subset=facts_for_analysis, inplace=True)

# Remplacer les valeurs NaN par 0
# df_nutrients.fillna(value=0, inplace=True)

# print("Nombre d'observations : {}".format(df_nutrients.shape[0]))
# df_nutrients.head()

# %% [markdown]
# Quelques chiffres pour comparer avant l’imputation.

# %%
df_nutrients[facts_for_analysis].count()
# Out:
# energy_100g           264321
# carbohydrates_100g    263163
# fat_100g              262976
# proteins_100g         263765
# fiber_100g             95824
# salt_100g             259026
# dtype: int64

# %%
df_nutrients[facts_for_analysis].describe()
# Out:
#         energy_100g  carbohydrates_100g       fat_100g  proteins_100g  \
# count  2.643210e+05       263163.000000  262976.000000  263765.000000
# mean   1.191303e+03           25.611418      15.587002       8.739337
# std    2.284270e+03           27.197341      19.271669       8.472980
# min    4.000000e-01            0.000000       0.000000       0.000000
# 25%    5.020000e+02            2.100000       1.300000       1.800000
# 50%    1.092000e+03           12.000000       8.800000       6.400000
# 75%    1.693000e+03           51.000000      24.000000      13.000000
# max    1.094259e+06          100.000000     100.000000     100.000000
#
#          fiber_100g      salt_100g
# count  95824.000000  259026.000000
# mean       2.780889       1.001284
# std        4.187478       1.892915
# min        0.000000       0.000000
# 25%        0.200000       0.080000
# 50%        1.600000       0.600000
# 75%        3.500000       1.300000
# max       99.000000     100.000000

# %% [markdown]
# Imputation KNN
#
# Nous allons imputer les valeurs manquantes avec l'algorithme des K Nearest Neighbours (KNN)

# %% [markdown]
# Démonstration avant imputation

# %%
# Plot de distribution avec superposition de loi normale
sns.set_style("whitegrid")
fig = plt.figure(figsize=(21, 30))
num_facts = df_nutrients[facts_for_analysis]
sub = 0

for i in num_facts:
    fig.add_subplot(4, 3, sub + 1)

    left, width = 0, 1
    bottom, height = 0, 1
    right = left + width
    top = bottom + height

    kstest = stats.kstest(num_facts[i].notnull(), 'norm')
    ax = sns.distplot(num_facts[i], fit=stats.norm, kde=False)
    ax.set_title("Distribution par rapport à la loi normale de {}".format(i))
    sub += 1
plt.show()

# %% [markdown]
# Nous comparerons le graphique après l'imputation pour juger de sa qualité. Plus le graphique après imputation se rapproche de celle avant l'imputation et plus le processus est un succès.

# %% [markdown]
# Imputation

# %%
# Entrainer le modèle d'imputation
sample_df_nutrients = df_nutrients[facts_for_analysis].sample(frac=0.20)

# Nous pouvons vérifier le meilleur « n_neighbors » à l’aide de GridSearchCV.
# Cependant, réserverons cela pour un autre projet afin de ne pas trop s’écarter du référentiel.
imputer = KNNImputer(n_neighbors=5, missing_values=np.nan)
imputer.fit(sample_df_nutrients)

# Appliquer le modèle
imputed_facts = imputer.transform(df_nutrients[facts_for_analysis])
imputed_df_nutrients = pd.DataFrame(imputed_facts, columns=facts_for_analysis)

for facts in facts_for_analysis:
    df_nutrients[facts] = imputed_df_nutrients[facts].values

# %% [markdown]
# Démonstration après imputation

# %%
# Plot de distribution avec superposition de loi normale
sns.set_style("whitegrid")
fig = plt.figure(figsize=(21, 30))
num_facts = df_nutrients[facts_for_analysis]
sub = 0

for i in num_facts:
    fig.add_subplot(4, 3, sub + 1)

    left, width = 0, 1
    bottom, height = 0, 1
    right = left + width
    top = bottom + height

    kstest = stats.kstest(num_facts[i].notnull(), 'norm')
    ax = sns.distplot(num_facts[i], fit=stats.norm, kde=False)
    ax.set_title("Distribution par rapport à la loi normale de {}".format(i))
    sub += 1
plt.show()

# %% [markdown]
# Nous remarquons qu'il n'y a aucune différence visible sur le graphique. L'imputation par KNN est un succès.

# %% [markdown]
# Quelques chiffres pour comparer après l’imputation :

# %%
df_nutrients[facts_for_analysis].count()
# Out:
# energy_100g           264321
# carbohydrates_100g    264321
# fat_100g              264321
# proteins_100g         264321
# fiber_100g            264321
# salt_100g             264321
# dtype: int64

# %%
df_nutrients[facts_for_analysis].describe()
# Out:
#         energy_100g  carbohydrates_100g       fat_100g  proteins_100g  \
# count  2.643210e+05       264321.000000  264321.000000  264321.000000
# mean   1.191303e+03           25.598134      15.559460       8.729662
# std    2.284270e+03           27.187163      19.261364       8.471340
# min    4.000000e-01            0.000000       0.000000       0.000000
# 25%    5.020000e+02            2.100000       1.300000       1.800000
# 50%    1.092000e+03           12.000000       8.800000       6.400000
# 75%    1.693000e+03           51.000000      24.000000      13.000000
# max    1.094259e+06          100.000000     100.000000     100.000000
#
#           fiber_100g      salt_100g
# count  264321.000000  264321.000000
# mean        2.259322       0.992393
# std         3.273285       1.879461
# min         0.000000       0.000000
# 25%         0.220000       0.080000
# 50%         1.342000       0.600000
# 75%         3.000000       1.300000
# max        99.000000     100.000000

# %% [markdown]
# Le changement des valeurs est mineur, ce qui confirme la qualité d’imputation.

# %% [markdown]
# ### Suppression des produits dont les valeurs des sous-ensembles sont incohérentes

# %% [markdown]
# Rappelez-vous que nous avons déjà éliminé les produits dont les faits sont négatifs ou supérieurs à 100g. Ici, nous allons simplement supprimer les produits qui ont des valeurs de faits incohérentes entre le niveau supérieur et leur sous-ensembles.

# %%
# Fonction permettant de supprimer les observations incohérentes
# ATTENTION : cette fonction fonctionne (😊) car les variables
# sont bien ordonnées.
def drop_observations_with_incoherent_breakdown(df, col_total,
                                                col_breakdown_start,
                                                col_breakdown_end, epsilon):
    breakdown_total = df.loc[:,
                             col_breakdown_start:col_breakdown_end].sum(axis=1)
    condition_filter = breakdown_total > (df[col_total] * (1 + epsilon))
    df.drop(df[condition_filter].index, inplace=True)


# tolérance pour la mesure des erreurs d'arrondi et des erreurs de protocole
epsilon = 0.1

# Glucides : supprimer les observations dont la somme de la répartition
# des glucides est supérieure au total des glucides (avec tolérance).
drop_observations_with_incoherent_breakdown(df_nutrients,
                                            col_total='carbohydrates_100g',
                                            col_breakdown_start='sugars_100g',
                                            col_breakdown_end='polyols_100g',
                                            epsilon=epsilon)

# Lipides : supprimer les observations dont la somme de la répartition
# des lipides est supérieure au total des lipides (avec tolérance).
drop_observations_with_incoherent_breakdown(
    df_nutrients,
    col_total='fat_100g',
    col_breakdown_start='saturated-fat_100g',
    col_breakdown_end='trans-fat_100g',
    epsilon=epsilon)

# Protéines : supprimer les observations dont la somme de la répartition
# des protéines est supérieure au total des protéines (avec tolérance).
drop_observations_with_incoherent_breakdown(
    df_nutrients,
    col_total='proteins_100g',
    col_breakdown_start='casein_100g',
    col_breakdown_end='serum-proteins_100g',
    epsilon=epsilon)

print("Nombre d'observations : {}".format(df_nutrients.shape[0]))
# Out:
# Nombre d'observations : 263733

# %% [markdown]
# ### Suppression des valeurs aberrantes par groupes de PNNS

# %% [markdown]
# Dans cette section, nous allons supprimer les produits aberrants dans chaque groupe PNNS. Un produit d'un groupe PNNS est considéré comme aberrant si l'une des valeurs suivantes est éloignée de plus de 3 sigma de la moyenne de son groupe PNNS :
#
# - energy_100g
# - carbohydrates_100g
# - fats_100g
# - proteins_100g
# - fiber_100g
# - salt_100g

# %%
# Fonction pour éliminer les valeurs aberrantes en ce qui concerne les
# variables de haut niveau des faits (définies dans facts_for_analysis)
def drop_outliers(group, nsigma=3):
    g = group.loc[:, facts_for_analysis]
    is_outlier = np.abs(g - g.mean()) > (nsigma * g.std())
    outliers = g[is_outlier.any(axis=1)]
    return group.drop(outliers.index, axis=0)


# Groupe de produits par groupes de PNNS
by_pnns = df_nutrients.groupby(['pnns_groups_1', 'pnns_groups_2'])

# Supprimer les valeurs aberrantes
df_nutrients = by_pnns.apply(drop_outliers)

# Remise à zéro de l'index car après le groupby, il s'agit
# d'un index multiple : pnns_groups_1 | pnns_groups_2 | row index
df_nutrients.reset_index(level=[0, 1], drop=True, inplace=True)

print("Nombre d'observations : {}".format(df_nutrients.shape[0]))
# Out:
# Nombre d'observations : 247582

# %% [markdown]
# Une fois les valeurs aberrantes supprimées, vérifions le nombre de produits par groupe PNNS.

# %%
# Obtenir le nombre de produits par groupes de PNNS
by_pnns = df_nutrients.groupby(['pnns_groups_1', 'pnns_groups_2'])
by_pnns.size().sort_values(ascending=False)
# Out:
# pnns_groups_1            pnns_groups_2
# Sugary snacks            Biscuits and cakes                  23284
#                          Sweets                              20676
# Composite foods          One dish meals                      19146
# Milk and dairy products  Cheese                              16068
# Fish meat eggs           Processed meat                      16063
# Fat and sauces           Dressings and sauces                12301
# Cereals and potatoes     Cereals                             11358
# Fish meat eggs           Meat                                10712
#                          Fish and seafood                     9643
# Milk and dairy products  Milk and yogurt                      8864
# Salty snacks             Salty and fatty products             8480
# Fruits and vegetables    Vegetables                           7908
# Beverages                Sweetened beverages                  7705
# Sugary snacks            Chocolate products                   7500
# Fat and sauces           Fats                                 6470
# Salty snacks             Appetizers                           5702
# Cereals and potatoes     Bread                                5650
# Fruits and vegetables    Fruits                               5147
# Beverages                Fruit juices                         5008
# Cereals and potatoes     Breakfast cereals                    4106
# Milk and dairy products  Dairy desserts                       3963
# Sugary snacks            Pastries                             3360
# Milk and dairy products  Ice cream                            3301
# Fruits and vegetables    Dried fruits                         3190
# Salty snacks             Nuts                                 3084
# Cereals and potatoes     Legumes                              2639
# Beverages                Unsweetened beverages                2595
# Composite foods          Pizza pies and quiche                2436
# Beverages                Artificially sweetened beverages     1776
# Fruits and vegetables    Soups                                1702
# Composite foods          Sandwiches                           1679
# Beverages                Plant based milk substitutes         1478
# Cereals and potatoes     Potatoes                             1388
# Fish meat eggs           Offals                                978
#                          Eggs                                  778
# Beverages                Fruit nectars                         723
#                          Teas and herbal teas and coffees      549
#                          Waters and flavored waters            172
# dtype: int64

# %% [markdown]
# Le groupe "Biscuits and cakes" contient 9640 produits; si nous voulons faire notre analyse avec seulement un échantillon de données, 98 observations par groupe (racine carrée de 9640) serait un minimum. Nous pouvons supprimer le groupe "Waters and flavored waters" avec ses 53 observations seulement.

# %%
# Conserver les observations des groupes PNNS qui contiennent au moins
# 98 produits (racine carrée de 9640  -> le plus grand groupe de PNNS)
size_min = 98
df_nutrients = by_pnns.filter(lambda x: x.shape[0] >= size_min)

print("Nombre d'observations : {}".format(df_nutrients.shape[0]))
# Out:
# Nombre d'observations : 247582

# %% [markdown]
# ### Statistiques : Macronutriments par groupes de PNNS
#
# Nos données sont maintenant nettoyées et nous pouvons passer à l'analyse et calculer des statistiques par groupes de pnns.

# %%
# Calculer les statistiques par groupes de PNNS
by_pnns = df_nutrients.groupby(['pnns_groups_1', 'pnns_groups_2'])
stats_by_pnns = by_pnns.describe()

# Construire un dataframe avec seulement
# la moyenne (juste pour la lisibilité)
means_by_pnns = stats_by_pnns.loc[:, (facts_for_analysis, 'mean')]

# Enlever le niveau 1 de l'index de la colonne
means_by_pnns.columns = means_by_pnns.columns.droplevel(1)

# Modifier l'ordre des variables
# (énergie d'abord, puis macronutriments).
means_by_pnns = means_by_pnns.reindex(columns=facts_for_analysis)
means_by_pnns.round(2)
# Out:
#                                                           energy_100g  \
# pnns_groups_1           pnns_groups_2
# Beverages               Artificially sweetened beverages        71.44
#                         Fruit juices                           192.21
#                         Fruit nectars                          196.24
#                         Plant based milk substitutes           308.46
#                         Sweetened beverages                    410.02
#                         Teas and herbal teas and coffees        98.51
#                         Unsweetened beverages                  157.04
#                         Waters and flavored waters              31.37
# Cereals and potatoes    Bread                                 1370.10
#                         Breakfast cereals                     1680.13
#                         Cereals                               1401.84
#                         Legumes                               1165.23
#                         Potatoes                               679.66
# Composite foods         One dish meals                         599.07
#                         Pizza pies and quiche                 1068.45
#                         Sandwiches                            1006.70
# Fat and sauces          Dressings and sauces                  1000.64
#                         Fats                                  3469.79
# Fish meat eggs          Eggs                                   575.75
#                         Fish and seafood                       755.69
#                         Meat                                   673.91
#                         Offals                                 893.55
#                         Processed meat                        1033.73
# Fruits and vegetables   Dried fruits                          1368.01
#                         Fruits                                 472.27
#                         Soups                                  171.78
#                         Vegetables                             221.52
# Milk and dairy products Cheese                                1405.25
#                         Dairy desserts                         546.22
#                         Ice cream                              859.57
#                         Milk and yogurt                        392.66
# Salty snacks            Appetizers                            1858.22
#                         Nuts                                  2610.94
#                         Salty and fatty products              1397.29
# Sugary snacks           Biscuits and cakes                    1795.19
#                         Chocolate products                    2310.26
#                         Pastries                              1535.44
#                         Sweets                                1428.76
#
#                                                           carbohydrates_100g  \
# pnns_groups_1           pnns_groups_2
# Beverages               Artificially sweetened beverages                3.49
#                         Fruit juices                                   10.48
#                         Vegetables                             0.69
# Milk and dairy products Cheese                                 1.40
#                         Dairy desserts                         0.15
#                         Ice cream                              0.14
#                         Milk and yogurt                        0.13
# Salty snacks            Appetizers                             1.54
#                         Nuts                                   0.55
#                         Salty and fatty products               1.71
# Sugary snacks           Biscuits and cakes                     0.57
#                         Chocolate products                     0.17
#                         Pastries                               0.79
#                         Sweets                                 0.14

# %% [markdown]
# Il peut être tentant de comparer les valeurs des moyennes et d'en tirer des conclusions faciles et rapides, mais ce n'est jamais une bonne idée de comparer des moyennes sans connaître leur écart-type. Le dataframe ci-dessus n'affiche que les moyennes pour des raisons de lisibilité et pour inviter notre curiosité à poser des questions auxquelles nous devons répondre plus sérieusement.

# %% [markdown]
# 1. Quels sont les aliments qui contiennent le plus de fibres, par ordre d'importance ?

# %%
# D'abord la réponse innocente en comparant simplement la moyenne
fiber_rich_groups = means_by_pnns.fiber_100g.sort_values(
    ascending=False).head(4)
fiber_rich_groups
# Out:
# pnns_groups_1          pnns_groups_2
# Cereals and potatoes   Legumes              7.483885
# Salty snacks           Nuts                 7.175828
# Cereals and potatoes   Breakfast cereals    6.713772
# Fruits and vegetables  Dried fruits         5.357312
# Name: fiber_100g, dtype: float64

# %% [markdown]
# Une meilleure approche serait de comparer les statistiques des groupes en traçant des boites à moustache.

# %%
# Construire un Dataframe avec seulement
# les produits des groupes de PNNS ci-dessus.
pnns_groups_rich_fiber = fiber_rich_groups.index.get_level_values(
    'pnns_groups_2')
df_nutrients_fiber = df_nutrients.loc[df_nutrients.pnns_groups_2.isin(
    pnns_groups_rich_fiber)]

# Tracer une boîte à moustache pour comparer
# les statistiques de chaque groupe.
sns.set(style="whitegrid")

plt.figure(figsize=(16, 8))
sns.boxplot(x='pnns_groups_2',
            y='fiber_100g',
            data=df_nutrients_fiber,
            order=pnns_groups_rich_fiber)

plt.xlabel('Groupe PNNS')
plt.ylabel('Fiber [gr]')
plt.title('Les 4 principaux groupes de PNNS riches en fibres')
plt.show()

# %% [markdown]
# Tout d'abord, nous pouvons constater que le classement serait différent en comparant les médianes; les noix seraient l'aliment qui contient le plus de fibres. Mais la bonne question à se poser est de savoir si les différences moyennes/médianes sont significatives ? Peut-on vraiment dire que les noix contiennent plus de fibres que les légumineuses, ou que les fruits secs ?
#
# Le test de Student, ou test t, peut nous aider à répondre à ces questions. L'hypothèse nulle consiste à dire que les moyennes sont les mêmes et que la différence observée est due au hasard. Le test t nous indique si nous pouvons ou non rejeter l'hypothèse nulle.

# %%
# Fonction permettant de calculer un test t
# indépendant avec  des résultats agréables à lire
# https://en.wikipedia.org/wiki/Student%27s_t-test#Independent_two-sample_t-test
def compute_ttest_ind(df, group_1, group_2, variable):
    stat, pvalue = ttest_ind(df.loc[df.pnns_groups_2 == group_1, variable],
                             df.loc[df.pnns_groups_2 == group_2, variable],
                             equal_var=False)
    print(
        "{} par rapport à {}\nstatistique: {}\np-value  : {}\nPeut-on rejeter l'hypothèse nulle ? : {}\n"
        .format(group_1, group_2, stat, pvalue, pvalue < 0.05))


compute_ttest_ind(df_nutrients_fiber, 'Nuts', 'Legumes', 'fiber_100g')
compute_ttest_ind(df_nutrients_fiber, 'Nuts', 'Dried fruits', 'fiber_100g')
compute_ttest_ind(df_nutrients_fiber, 'Nuts', 'Breakfast cereals',
                  'fiber_100g')
compute_ttest_ind(df_nutrients_fiber, 'Dried fruits', 'Breakfast cereals',
                  'fiber_100g')
# Out:
# Nuts par rapport à Legumes
# statistique: -2.5354005507450874
# p-value  : 0.011273453872486747
# Peut-on rejeter l'hypothèse nulle ? : True
#
# Nuts par rapport à Dried fruits
# statistique: 24.296793267922954
# p-value  : 1.3192361455400195e-124
# Peut-on rejeter l'hypothèse nulle ? : True
#
# Nuts par rapport à Breakfast cereals
# statistique: 6.930817103165064
# p-value  : 4.564663052407713e-12
# Peut-on rejeter l'hypothèse nulle ? : True
#
# Dried fruits par rapport à Breakfast cereals
# statistique: -18.655640841078835
# p-value  : 1.0422833967083619e-75
# Peut-on rejeter l'hypothèse nulle ? : True

# %% [markdown]
# Nous parvenons à rejeter l'hypothèse nulle en comparant les noix et les légumineuses. Nous pouvons dire que les fruits à coque contiennent plus de fibres que les légumineuses, il serait donc logique d'établir un classement.
#
# Comparons la composition en fibres du groupe "Fruits et légumes".

# %%
# Construire un Dataframe avec seulement les produits
# du groupe 1 des PNNS "Fruits and vegetables".
df_nutrients_fiber = df_nutrients.loc[df_nutrients.pnns_groups_1 ==
                                      'Fruits and vegetables']

# Traçer une boîte à moustache pour comparer
# les statistiques de chaque groupe.
sns.set(style="whitegrid")

plt.figure(figsize=(16, 8))
sns.boxplot(x='pnns_groups_2',
            y='fiber_100g',
            data=df_nutrients_fiber,
            order=['Dried fruits', 'Vegetables', 'Fruits', 'Soups'])

plt.xlabel('Groupe PNNS')
plt.ylabel('Fibre [gr]')
plt.title('Les fibres dans les fruits et légumes')
plt.show()

# %% [markdown]
# Ici, il ne fait aucun doute que la différence entre les fruits, les légumes et les fruits secs est significative.

# %%
# Calculer un test t
compute_ttest_ind(df_nutrients_fiber, 'Dried fruits', 'Fruits', 'fiber_100g')
compute_ttest_ind(df_nutrients_fiber, 'Vegetables', 'Fruits', 'fiber_100g')
# Out:
# Dried fruits par rapport à Fruits
# statistique: 60.0135793379765
# p-value  : 0.0
# Peut-on rejeter l'hypothèse nulle ? : True
#
# Vegetables par rapport à Fruits
# statistique: 21.845784844374105
# p-value  : 1.011244195231729e-103
# Peut-on rejeter l'hypothèse nulle ? : True

# %% [markdown]
# La valeur p (p-value) est très faible, ce qui indique que nous pouvons rejeter avec confiance l'hypothèse nulle.
#
# En se renseignant sur internet, on apprend ceci :
#
# Un morceau de fruit sec contient à peu près la même quantité de nutriments que le fruit frais, mais condensés dans un emballage beaucoup plus petit. En poids, les fruits secs contiennent jusqu'à 3,5 fois plus de fibres, de vitamines et de minéraux que les fruits frais. Il y a quelques exceptions, par exemple, la teneur en vitamine C est considérablement réduite lorsque le fruit est séché.

# %% [markdown]
# ### Corrélation entre l'énergie et la composition en macronutriments

# %% [markdown]
# Avec le dernier dataframe, nous pourrions répondre à de nombreuses questions intéressantes, telles que les aliments les plus équilibrés, les aliments ayant le ratio le plus élevé de graisses, etc. Mais nous allons plutôt nous concentrer sur un sujet différent : l'énergie. Nous allons étudier la corrélation entre l'énergie et la composition des macronutriments et leur apport calorique respectif.

# %%
x_vars = [
    'carbohydrates_100g', 'fat_100g', 'proteins_100g', 'fiber_100g',
    'salt_100g'
]

y_vars = ['energy_100g']

# Obtenir des nuage de points de l'énergie par rapport à
# chaque macronutriment pour tous les groupes d'aliments.
g = sns.pairplot(df_nutrients, kind='scatter', x_vars=x_vars, y_vars=y_vars)
g.fig.suptitle(
    'Énergie par rapport aux macronutriments (tous les groupes PNNS)')
g.set(xlim=(0, 100))
g.set(ylim=(0, 4000))
plt.show()

# %% [markdown]
# Nous pouvons constater une corrélation linéaire entre l'énergie et les lipides. Dans le nuage de points des glucides, nous pouvons également deviner une corrélation linéaire. Elle provient probablement d'un type d'aliment spécifique. Concernant les protéines, les fibres et le sel, il n'y a pas de corrélation visible évidente.
#
# Dans le dataframe présentant la répartition des macronutriments par groupes de PNNS, on peut voir que :
#
# 1. Les produits gras (le groupe "Fats") ont tendance à avoir essentiellement des lipides.
# 2. Les fruits ont tendance à contenir essentiellement des glucides.
# 3. Il n'y a pas d'aliments qui contiennent essentiellement des protéines dans le même ordre que les fruits et les graisses, respectivement pour les glucides et les lipides.
# 4. Les légumineuses sont des aliments bien équilibrés et contiennent des glucides, des lipides et des protéines en bonne proportion.
#
# Nous profiterons de la forte proportion de lipides et de glucides des produits gras et des fruits pour estimer leur apport calorique respectif. Ensuite, nous déduirons l'apport calorique en protéines des légumineuses en soustrayant à leur énergie connue l'énergie fournie par les graisses et les glucides.

# %%
# Fonction pour tracer des nuages de points
# pour un groupe spécifique de PNNS 2
def pairplot_for_pnns_group(df,
                            pnns_group,
                            x_vars,
                            y_vars,
                            title,
                            xlim=(0, 100),
                            ylim=(0, 4000)):
    g = sns.pairplot(df[df.pnns_groups_2 == pnns_group],
                     kind='scatter',
                     x_vars=x_vars,
                     y_vars=y_vars)
    g.fig.suptitle(title)
    g.set(xlim=xlim)
    g.set(ylim=ylim)
    plt.show()


# Scatter plots of the energy versus each macronutrients for fruits only
pairplot_for_pnns_group(
    df_nutrients, 'Fruits', x_vars, y_vars,
    'Énergie par rapport aux Macronutriments (Fruits uniquement)')

# %% [markdown]
# Si l'on considère uniquement les fruits, on observe une corrélation linéaire claire entre l'énergie et les glucides. Nous pouvons calculer une régression linéaire. La pente nous donnera une approximation de l'apport calorique des glucides.

# %%
# Conversion de kJ en kcal
kj_to_kcal = 0.239006

# Conserver uniquement les fruits
df_fruits = df_nutrients[df_nutrients.pnns_groups_2 == 'Fruits'].copy()

# Calculer la régression linéaire pour les fruits
# uniquement entre l'énergie et les glucides.
slope_carbohydrates, intercept_carbohydrates, r_value, p_value, std_err = linregress(
    x=df_fruits['carbohydrates_100g'], y=df_fruits['energy_100g'])

print("Équation de régression linéaire [kJ]    : Énergie = {} * Glucides + {}".
      format(slope_carbohydrates, intercept_carbohydrates))
print("Équation de régression linéaire [kcal]  : Énergie = {} * Glucides + {}".
      format(slope_carbohydrates * kj_to_kcal,
             intercept_carbohydrates * kj_to_kcal))
print("Énergie des Glucides [kJ]   apportent : {}".format(slope_carbohydrates))
print("Énergie des Glucides [kcal] apportent : {}".format(slope_carbohydrates *
                                                          kj_to_kcal))
# Out:
# Équation de régression linéaire [kJ]    : Énergie = 16.71443791820236 * Glucides + 56.45335347939255
# Équation de régression linéaire [kcal]  : Énergie = 3.994850949077873 * Glucides + 13.492690201695694
# Énergie des Glucides [kJ]   apportent : 16.71443791820236
# Énergie des Glucides [kcal] apportent : 3.994850949077873

# %% [markdown]
# 1 gramme de glucides fournit environ 4 kilocalories d'énergie.
#
# Au passage, un grand merci à **Mohamed Laaraiedh** de m’avoir enseigné la "Méthode Data Scientist" pour retrouver une information 😊

# %% [markdown]
# Faisons de même pour les produits gras uniquement

# %%
# Nuage de points de l'énergie en fonction de chaque
# macronutriment pour les produits gras uniquement.
pairplot_for_pnns_group(
    df_nutrients, 'Fats', x_vars, y_vars,
    'Énergie par rapport aux macronutriments (Produits gras uniquement)')

# %% [markdown]
# Nous avons une belle corrélation linéaire entre l'énergie et les lipides.

# %%
# Conserver uniquement les produits gras
df_fats = df_nutrients[df_nutrients.pnns_groups_2 == 'Fats'].copy()

# Calculer l'énergie sans la contribution des glucides (~ énergie provenant des lipides)
df_fats[
    'energy_fats_100g'] = df_fats.energy_100g - slope_carbohydrates * df_fats.carbohydrates_100g

# Calculer la régression linéaire pour les produits gras uniquement
# entre l'énergie (sans la contribution des glucides) et les lipides.
slope_fats, intercept_fats, r_value, p_value, std_err = linregress(
    x=df_fats['fat_100g'], y=df_fats['energy_fats_100g'])

print("Équation de régression linéaire [kJ]    : Énergie = {} * Lipides + {}".
      format(slope_fats, intercept_fats))
print("Équation de régression linéaire [kcal]  : Énergie = {} * Lipides + {}".
      format(slope_fats * kj_to_kcal, intercept_fats * kj_to_kcal))
print("Énergie des Lipides [kJ]   apportent : {}".format(slope_fats))
print("Énergie des Lipides [kcal] apportent : {}".format(slope_fats *
                                                         kj_to_kcal))
# Out:
# Équation de régression linéaire [kJ]    : Énergie = 36.06396840109758 * Lipides + 137.77990209077734
# Équation de régression linéaire [kcal]  : Énergie = 8.619504831672728 * Lipides + 32.930223279108326
# Énergie des Lipides [kJ]   apportent : 36.06396840109758
# Énergie des Lipides [kcal] apportent : 8.619504831672728

# %% [markdown]
# 1 gramme de graisses fournit environ 9 kilocalories d'énergie.

# %% [markdown]
# Nous pouvons maintenant déduire des légumineuses l'apport calorique des protéines

# %%
# Nuage de points de l'énergie en fonction de chaque macronutriment pour les légumineuses uniquement.
pairplot_for_pnns_group(
    df_nutrients, 'Legumes', x_vars, y_vars,
    'Énergie par rapport aux macronutriments (légumineuses uniquement)')

# %% [markdown]
# Intéressant, nous pouvons voir différents clusters. Cela signifie que notre groupe PNNS de Légumineuses est trop large et pourrait être divisé en plusieurs sous-groupes plus spécifiques.
#
# Nous pouvons deviner une corrélation linéaire pour les trois macronutriments.

# %%
# Calculez la régression linéaire pour les fruits uniquement entre l'énergie et les glucides.
df_legumes = df_nutrients[df_nutrients.pnns_groups_2 == 'Legumes'].copy()

# Calculez l'énergie sans la contribution des glucides.
df_legumes['energy_proteins_100g'] = df_legumes.energy_100g \
    - slope_carbohydrates * df_legumes.carbohydrates_100g \
    - slope_fats * df_legumes.fat_100g

# %% [markdown]
# Avant de calculer une régression linéaire, nous devons vérifier s'il existe réellement une corrélation linéaire entre les protéines et l'énergie que nous venons de calculer

# %%
# Tracer un nuage de points de l'énergie des protéines par rapport aux protéines.
sns.lmplot(data=df_legumes,
           x='proteins_100g',
           y='energy_proteins_100g',
           fit_reg=False,
           scatter_kws={
               "marker": "D",
               "s": 20
           },
           size=8)
plt.xlim(0, 100)
plt.xlabel('Poids des protéines (gr)')
plt.ylabel('Énergie provenant des protéines (calculée)')
plt.title(
    "Énergie calculée des protéines par rapport au poids des protéines (Légumineuses uniquement)"
)
plt.show()

# %%
# Calculer la régression linéaire pour les légumineuses uniquement entre
# l'énergie (sans les apports en glucides et lipides) et les protéines
slope_proteins, intercept_proteins, r_value, p_value, std_err = linregress(
    x=df_legumes['proteins_100g'], y=df_legumes['energy_proteins_100g'])

print(
    "Équation de régression linéaire [kJ]    : Énergie = {} * Protéines + {}".
    format(slope_proteins, intercept_proteins))
print(
    "Équation de régression linéaire [kcal]  : Énergie = {} * Protéines + {}".
    format(slope_proteins * kj_to_kcal, intercept_proteins * kj_to_kcal))
print("Énergie des Protéines [kJ]   apportent : {}".format(slope_proteins))
print("Énergie des Protéines [kcal] apportent : {}".format(slope_proteins *
                                                           kj_to_kcal))
# Out:
# Équation de régression linéaire [kJ]    : Énergie = 18.13553159719069 * Protéines + 70.0364528790708
# Équation de régression linéaire [kcal]  : Énergie = 4.334500864918158 * Protéines + 16.739132456815195
# Énergie des Protéines [kJ]   apportent : 18.13553159719069
# Énergie des Protéines [kcal] apportent : 4.334500864918158

# %% [markdown]
# 1 gramme de protéines fournit environ 4 kilocalories d'énergie.

# %% [markdown]
# Nous avons utilisé une méthode empirique pour découvrir le rapport calorique fourni par les glucides, les lipides et les protéines. Il est tentant de dire que la formule permettant de calculer l'énergie provenant du poids des trois macronutriments est la suivante :
#
#     Énergie [kJ] = 16.703 * Glucides [g] + 36.016 * Graisses [g] + 18.245 * Protéines [g]
#
# ou
#
#     Énergie [kcal] = 3.992 * Glucides [g] + 8.608 * Graisses [g] + 4.360 * Protéines [g].
#
# Et pour s'en souvenir plus facilement :
#
#     Énergie [kcal] = 9 * Graisses [g] + 4 * Glucides [g] + 4 * Protéines [g] (9/4/4).
#
# Note : d'après cette source https://www.cerin.org/glossaire/calorie/ le véritable ratio serait (9/4/4) ce qui correspond à notre modèle.

# %% [markdown]
# Nous pouvons évaluer la qualité de notre "modèle" très basique et empirique en calculant l'énergie prédite par le modèle pour chaque produit et en comparant l'écart type par rapport à l'énergie connue. Nous exclurons les groupes d'aliments utilisés pour construire notre "modèle".

# %%
# Conserver uniquement les aliments non utilisés pendant le processus de modelage
df_model_test = df_nutrients[~df_nutrients.pnns_groups_2.
                             isin(['Fruits', 'Fats', 'Legumes'])].copy()

# Calculer l'énergie attendue
df_model_test['expected_energy_100g'] = slope_carbohydrates * df_model_test.carbohydrates_100g + \
    slope_fats * df_model_test.fat_100g + \
    slope_proteins * df_model_test.proteins_100g

# Calculer la valeur absolue de l'écart en pourcentage
df_model_test['energy_deviation'] = np.abs(
    df_model_test.expected_energy_100g -
    df_model_test.energy_100g) / df_model_test.energy_100g * 100

# %%
slope_carbohydrates
# Out:
# 16.71443791820236

# %%
# Obtenir des statistiques de l'énergie calculé
df_model_test.expected_energy_100g.describe()
# Out:
# count    233326.000000
# mean       1084.377087
# std         679.514128
# min           0.000000
# 25%         494.630019
# 50%        1026.834926
# 75%        1606.249828
# max        3310.215480
# Name: expected_energy_100g, dtype: float64

# %%
# Obtenir des statistiques de l'écart type
df_model_test.energy_deviation.describe()
# Out:
# count    233326.000000
# mean         24.938115
# std         956.442758
# min           0.000016
# 25%           1.274607
# 50%           2.566485
# 75%           4.690003
# max      157420.172607
# Name: energy_deviation, dtype: float64

# %% [markdown]
# Avec une moyenne à environ 25% c'est correct pour un "modèle" empirique. Nous pouvons donc l'appliquer à notre jeu de données.

# %%
# Obtenir des statistiques de l'énergie avant application du modèle
df_nutrients['energy_100g'].describe()
# Out:
# count    247582.000000
# mean       1159.501142
# std         795.149145
# min           0.400000
# 25%         485.000000
# 50%        1058.000000
# 75%        1670.000000
# max        6556.000000
# Name: energy_100g, dtype: float64

# %%
kstest = stats.kstest(df_nutrients['energy_100g'].notnull(), 'norm')
ax = sns.distplot(df_nutrients['energy_100g'], fit=stats.norm, kde=False)
ax.set_title("Distribution par rapport à la loi normale d'energy_100g")
plt.show()

# %%
# Application du modèle sur le jeu de données
df_nutrients['energy_100g'] = slope_carbohydrates * df_nutrients.carbohydrates_100g + \
    slope_fats * df_nutrients.fat_100g + \
    slope_proteins * df_nutrients.proteins_100g

# %%
# Obtenir des statistiques de l'énergie après application du modèle
df_nutrients['energy_100g'].describe()
# Out:
# count    247582.000000
# mean       1130.050687
# std         765.920294
# min           0.000000
# 25%         486.374716
# 50%        1038.934096
# 75%        1642.170224
# max        3793.598545
# Name: energy_100g, dtype: float64

# %%
kstest = stats.kstest(df_nutrients['energy_100g'].notnull(), 'norm')
ax = sns.distplot(df_nutrients['energy_100g'], fit=stats.norm, kde=False)
ax.set_title("Distribution par rapport à la loi normale d'energy_100g")
plt.show()

# %% [markdown]
# Théoriquement le nombre maximale de kilojoule que nous pouvons obtenir dans 100g est de 3765,6kj.
# Avec 3730kj, nous pouvons confirmé avoir supprimé les outliers.

# %%
# Conversion en kcal
df_nutrients['energy-kcal_100g'] = df_nutrients['energy_100g'] * kj_to_kcal

# %% [markdown]
# ### Conclusion
#
# Nous avons terminé notre dernier sujet d'analyse. Nous avons étudié la répartition des macronutriments dans différents aliments et utilisé le test t pour vérifier si les différences observées dans la répartition des macronutriments sont significatives ou non. Nous avons également étudié la corrélation entre l'énergie et chaque macronutriment (glucides, lipides et protéines).
#
# Nous avons constaté que les fibres et le sel, même s'ils sont indiqués sur chaque étiquette alimentaire, ne contribuent pas à l'énergie ou du moins pas dans la même amplitude que les glucides, les lipides et les protéines. On peut rappeler les règles suivantes : graisses 9 / glucides 4 / protéines 5 kilocalories par gramme.

# %% [markdown]
# # Exportation des données

# %% [markdown]
# Nous sommes passés par des étapes de nettoyage dont nous avons tenté de justifier par des analyses statistiques.
#
# Dorénavant, nos données sont prêtes à être transmises aux agents de Santé Publique afin qu’ils puissent les analyser.
#
# Cette base de données contient :
# - Des données issues de source vérifié et validé
# - Uniquement des produits complété et approuvé par Open Food Facts
# - Seulement des produits alimentaires disponibles en France
# - Tous les allergènes sont nettoyés et prête à être enquêté
# - 100% des faits ont des macronutriments complets et réalistes (complété à l'aide d'une imputation KNN)

# %%
# Nous fusionnons les dataframes avec les données nettoyées
# Cependant, il serait préférable de ne pas les fusionner et de créer
# une base de données avec une table pour chaque dataframes

df_allergens_fr = df_allergens[['code', 'allergen', 'allergen_translation']]
df_state = df_states['Complet']
df_fr_min = df_fr[[
    'sodium_100g', 'nutriscore_score', 'nova_group',
    'nutriscore_grade', 'nutrition-score-fr_100g', 'image_url'
]]

df_nutrients_w_allergens = df_nutrients.merge(df_allergens_fr,
                                              how='left',
                                              on='code')
df_nutrients_w_allergens = df_nutrients_w_allergens.drop_duplicates(
    subset=['code'])
df_n_and_a_w_state = df_nutrients_w_allergens.merge(df_state,
                                                    how="left",
                                                    on=["code"])
df_fr_cols_to_keep = df_fr.columns.difference(df_n_and_a_w_state.columns)
df_final_all_cols = df_n_and_a_w_state.merge(df_fr[df_fr_cols_to_keep],
                                             on=['code'],
                                             how='left')
df_final_min = df_n_and_a_w_state.merge(df_fr_min, on=['code'], how='left')

# Définir code comme index du dataframe.
df_final_min.set_index('code', inplace=True)
df_final_all_cols.set_index('code', inplace=True)

# %%
df_final_all_cols.to_csv(data_path +
                         'fr.openfoodfacts.org.products.cleaned.csv')
df_final_min.to_csv(data_path +
                    'fr.openfoodfacts.org.products.cleaned.minimal.csv')

# %% [markdown]
# # Transfert vers PostgreSQL

# %%
# Veuillez entrer vos identifiants dans le fichier .env
load_dotenv()

param_dic = {
    "host": os.getenv("host"),
    "database": os.getenv("database"),
    "user": os.getenv("user"),
    "password": os.getenv("password")
}

# %%
def connect(params_dic):
    """ Connexion au serveur de base de données PostgreSQL """
    conn = None
    try:
        # connect to the PostgreSQL server
        print('Connexion à la base de données PostgreSQL...')
        conn = psycopg2.connect(**params_dic)
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        sys.exit(1)
    print("Connexion réussie")
    return conn


conn = connect(param_dic)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %%
connect = "postgresql+psycopg2://%s:%s@%s:5432/%s" % (
    param_dic['user'], param_dic['password'], param_dic['host'],
    param_dic['database'])


def to_alchemy(df):
    engine = create_engine(connect)
    df.to_sql('off', con=engine, index=True, if_exists='replace')
    print("Envoi à la base de données réussie")

# %%
to_alchemy(df_final_all_cols)
# Out:
# to_sql() done (sqlalchemy)
